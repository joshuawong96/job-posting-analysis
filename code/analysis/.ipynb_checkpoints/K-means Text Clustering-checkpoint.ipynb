# %%
import pandas as pd
import numpy as np
import re

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

import os

# %%
# for reproducibility
random_state = 0

# %% [markdown]
# ## Load Data

# %%
base_directory = "C:/Users/Gi Han/OneDrive - Singapore Management University/Documents/GitHub/job-posting-analysis"

# %% [markdown]
# Linkedin Data

# %%
directory = os.chdir(f"{base_directory}/data/raw/Linkedin")
files = os.listdir(".")
files
# Out:
# ['cloud_links.csv',
#  'cloud_posts_darren.csv',
#  'cloud_posts_gihan.csv',
#  'cloud_posts_joshua.csv',
#  'cloud_posts_lingjia.csv',
#  'cloud_posts_steph.csv']

# %%
relevant_csv = [x for x in files if 'cloud_posts' in x]
relevant_csv
# Out:
# ['cloud_posts_darren.csv',
#  'cloud_posts_gihan.csv',
#  'cloud_posts_joshua.csv',
#  'cloud_posts_lingjia.csv',
#  'cloud_posts_steph.csv']

# %%
# Combine all csv
linkedin_df = pd.concat(map(pd.read_csv, relevant_csv), ignore_index=True, axis=0)
linkedin_df.head(3)
# Out:
#                                jobTitle           jobLocation  \
# 0     Technical Content Writer (Infura)  Singapore, Singapore
# 1  Software Engineering (DevOps) Intern  Singapore, Singapore
# 2                   Expansion Associate  Singapore, Singapore
#
#    applicantsCount  viewsCount  \
# 0             11.0        84.0
# 1             16.0       145.0
# 2              9.0       120.0
#
#                                  jobPosterProfileUrl  \
# 0                                                NaN
# 1                                                NaN
# 2  https://www.linkedin.com/in/ACoAAB1CaW0BuleRsg...
#
#                    postedAt appliesClosed  \
# 0  2022-03-11T23:32:47.000Z         False
# 1  2022-01-20T04:08:28.000Z         False
# 2  2022-03-11T12:05:49.000Z         False
#
#                                             applyUrl  \
# 0  https://consensys.net/open-roles/gh_jid?gh_jid...
# 1  https://razer.wd3.myworkdayjobs.com/en-US/Care...
# 2  https://jobs.lever.co/Qashier/b8b66407-aff4-47...
#
#                                       jobDescription remoteAllowed  ...  \
# 0  About ConsenSys\r\n\r\nAt ConsenSys we have a ...         False  ...
# 1  Getting onboard Razer will place you on a glob...         False  ...
# 2  Want to be part of the fastest growing startup...         False  ...
#
#   matchedSkills                                  jobFunctions  \
# 0           NaN  Marketing, Public Relations, Writing/Editing
# 1           NaN           Engineering, Information Technology
# 2           NaN              Business Development, Consulting
#
#                                        jobIndustries  \
# 0                                  Computer Software
# 1                               Consumer Electronics
# 2  Information Technology & Services, Financial S...
#
#             appliesClosedAt    jobType  \
# 0  2022-04-10T23:32:46.000Z  Full-time
# 1  2022-03-16T04:08:28.000Z  Full-time
# 2  2022-04-10T12:05:49.000Z  Full-time
#
#                                            jobUrl  \
# 0  https://www.linkedin.com/jobs/view/2952827007/
# 1  https://www.linkedin.com/jobs/view/2918469480/
# 2  https://www.linkedin.com/jobs/view/2952512532/
#
#                                          jobImageUrl  \
# 0  https://media-exp1.licdn.com/dms/image/C4E0BAQ...
# 1  https://media-exp1.licdn.com/dms/image/C510BAQ...
# 2  https://media-exp1.licdn.com/dms/image/C560BAQ...
#
#                   timestamp                                           query  \
# 0  2022-03-14T11:16:31.849Z  https://www.linkedin.com/jobs/view/2952827007/
# 1  2022-03-14T11:16:35.635Z  https://www.linkedin.com/jobs/view/2918469480/
# 2  2022-03-14T11:16:39.354Z  https://www.linkedin.com/jobs/view/2952512532/
#
#   error
# 0   NaN
# 1   NaN
# 2   NaN
#
# [3 rows x 22 columns]

# %%
linkedin_df.columns
# Out:
# Index(['jobTitle', 'jobLocation', 'applicantsCount', 'viewsCount',
#        'jobPosterProfileUrl', 'postedAt', 'appliesClosed', 'applyUrl',
#        'jobDescription', 'remoteAllowed', 'companyName', 'companyUrl',
#        'matchedSkills', 'jobFunctions', 'jobIndustries', 'appliesClosedAt',
#        'jobType', 'jobUrl', 'jobImageUrl', 'timestamp', 'query', 'error'],
#       dtype='object')

# %% [markdown]
# MonsterSg

# %%
directory = os.chdir(f"{base_directory}/data/cleaned/")
files = os.listdir(".")
files
# Out:
# ['.ipynb_checkpoints',
#  'All_MonsterSg.csv',
#  'Cloud Computing_MonsterSg.csv',
#  'Cloud_MonsterSg.csv',
#  'foo.png',
#  'Wordcloud Visualisations (All Monster SG CSV).ipynb',
#  'word_test.png']

# %%
monster_df = pd.read_csv('All_MonsterSg.csv') 
monster_df.head(3)
# Out:
#                                         job_title               company  \
# 0                         Senior Python Developer                  Citi
# 1  Senior Partner Solutions Architect (Microsoft)                Amazon
# 2                                   IT Technician  Ascend Com Pte. Ltd.
#
#                salary   job_type years_experience  \
# 0                 NaN  permanent              NaN
# 1                 NaN  permanent              NaN
# 2  ['24000', '36000']  permanent       ['2', '5']
#
#                                           tech_stack  \
# 0                                                NaN
# 1                                                NaN
# 2  ['Switches', 'Mac', 'Windows 10', 'Cloud Compu...
#
#                                      job_description  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1  Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 2  Responsibilities:\r\nProvide helpdesk support ...
#
#                                     industry function  \
# 0  ['Banking/Accounting/Financial Services']   ['IT']
# 1                    ['Internet/E-commerce']   ['IT']
# 2                                  ['Other']   ['IT']
#
#                               roles date_posted  \
# 0  ['Software Engineer/Programmer']  2022-02-18
# 1  ['Software Engineer/Programmer']  2022-02-18
# 2   ['Other Software/Hardware/EDP']  2022-02-19
#
#                                                  url
# 0  https://www.monster.com.sg/seeker/job-details?...
# 1  https://www.monster.com.sg/seeker/job-details?...
# 2  https://www.monster.com.sg/seeker/job-details?...

# %% [markdown]
# NodeFlair

# %%
directory = os.chdir(f"{base_directory}/data/raw/nodeflair")
files = os.listdir(".")
files
# Out:
# ['nodeflair_jobpostings.csv', 'nodeflair_links.csv']

# %%
nodeflair_df = pd.read_csv('nodeflair_jobpostings.csv') 
nodeflair_df.head(3)
# Out:
#    Unnamed: 0          URL         Date posted  \
# 0           0  /jobs/53907  about 11 hours ago
# 1           1  /jobs/53898  about 11 hours ago
# 2           2  /jobs/53894  about 11 hours ago
#
#                                                 data  \
# 0  ['ReactJS Developer (Full Stack)', 'Apar Techn...
# 1  ['Manager, SRE', 'Rakuten Viki', ['Manager'], ...
# 2  ['DevOps Engineer', 'GovTech', ['Junior'], '$5...
#
#                         Job Title       Company Name          Seniority  \
# 0  ReactJS Developer (Full Stack)  Apar Technologies  ['Mid', 'Junior']
# 1                    Manager, SRE       Rakuten Viki        ['Manager']
# 2                 DevOps Engineer            GovTech         ['Junior']
#
#                           Salary   Job Type       Years of Experience  \
# 0  $6,419 - $8,819 SGD / Monthly  Permanent                 2-3 years
# 1                              -  Permanent  Information not provided
# 2  $5,800 - $9,600 SGD / Monthly  Permanent          At least 2 years
#
#                                           Tech Stack  \
# 0  ['Docker', 'CloudFoundry', 'Spring', 'SonarQub...
# 1  ['Docker', 'API', 'PagerDuty', 'GKE', 'ELK', '...
# 2  ['Docker', 'DockerCompose', 'Fluentd', 'Clair'...
#
#                                             Job Desc cleaned_date
# 0  We are looking for a candidate to fill in the ...   2022-03-10
# 1  The SRE team at Viki is responsible for buildi...   2022-03-10
# 2  Our team in GovTech works on highly impactful ...   2022-03-10

# %%
df = pd.concat([linkedin_df['jobTitle'], monster_df['job_title'], nodeflair_df['Job Title']], ignore_index=True)
df
# Out:
# 0             Technical Content Writer (Infura)
# 1          Software Engineering (DevOps) Intern
# 2                           Expansion Associate
# 3                               Cloud Architect
# 4           Cloud Infrastructure Engineer [MSS]
#                           ...
# 12118                           DevOps Engineer
# 12119                           DevOps Engineer
# 12120                           DevOps Engineer
# 12121                         Software Engineer
# 12122    Sr. Site Reliability Engineer - Hadoop
# Length: 12123, dtype: object

# %% [markdown]
# ## Cleaning Data

# %%
# Drop Duplicates
df.drop_duplicates(inplace=True)
df.reset_index(inplace=True, drop=True)
df
# Out:
# 0                       Technical Content Writer (Infura)
# 1                    Software Engineering (DevOps) Intern
# 2                                     Expansion Associate
# 3                                         Cloud Architect
# 4                     Cloud Infrastructure Engineer [MSS]
#                               ...
# 6945     Digital Solutions Consultant (Loyalty Solutions)
# 6946    Senior/ Infrastructure Engineer, Endpoint Secu...
# 6947    [INTERNSHIP] Agile Software Engineer Intern - ...
# 6948    Associate Software Engineer, Secured Infrastru...
# 6949               Sr. Site Reliability Engineer - Hadoop
# Length: 6950, dtype: object

# %%
print(list(df))
# Out:
# ['Technical Content Writer', 'Software Engineering  Intern', 'Expansion Associate', 'Cloud Architect', 'Cloud Infrastructure Engineer', 'Cloud Storage Engineer', 'Cloud Native Developer - Traffic Scheduling', 'Cloud Operations Engineer', 'Associate Solution Sales Director - Cloud', 'Partner Specialist', 'Infrastructure Engineer - remote', 'Internship : Product Management - Onboarding Experience', 'Cloud Native Developer - Elastic Machine Platform', 'Segment Marketing Manager', 'Cloud Native Developer - Computing Platform', 'Sales Specialist Hybrid Cloud', 'Software Engineer Intern', 'Cloud Native Developer - DevOps Platform', 'Technology Consulting Enterprise Applications & Cloud  Senior Associate', 'IT Cloud Security Engineer', 'Customer Engineering Manager Digital Native Customers Google Cloud', 'IT Cloud Architect', 'Data Engineer', 'Cloud & IT Transformation - Japanese Speaking - Senior Associate', 'Cloud Security Engineer', 'Cloud Systems Engineer', 'Software Engineer - Cloud Platform', 'Technical Account Manager', 'AIML Specialist', 'Cloud and IT Transformation - Dynamics   - Senior Associate', 'Technology Consulting Enterprise Applications & Cloud  Senior Associate', 'Dedicated Region Cloud Specialist PaaSIaaS JAPAC', 'Cloud Solutions Expert', 'Analytics Engineer - Consumer Product', 'SeniorData Scientist', 'DevOps Engineer', 'Manager - Cloud Solutions Architect_Financial Services - SG', 'Cloud Enterprise Solution Architect', 'HR Business Partner', 'Financial Services Advisory Head of Cloud & Data Centre-of-Excellence', 'Data Center Sales Specialist', 'AWS Cloud Operations Engineer', 'Lead Software Engineer  IT – Digital Franchise Platform', 'Cloud DevSecOps Engineer', 'Business Program Manager', 'Cloud Security  Manager Technology Consulting', 'Senior Cloud Software Engineer', 'Global Product PlanningLaunch Manager: Monitor Stands', 'Intern Software Engineer', 'Cloud Security Specialist', 'Regional Cloud Sales Executive', 'Cloud Security DevOps Engineer', 'Intern Developer Relations Software Engineer – Identity', 'Data Analyst Data Management Governance & Data Analytics', 'Partner Specialist', 'Cloud and IT Transformation - Cloud Architect  - Manager', 'Cloud & DevSecOps Architect', 'AWS SOC Support Engineer', 'Cloud Solution Architect', 'Senior Full Stack Java & Cloud Developer Payments Associate', 'Lead Cloud Engineer', 'Cloud Engineer', 'Intern Software Development - Cloud Product Data Management', 'Business Operation Program Manager Data Center Planning and Delivery', 'Cloud Infrastructure Architect', 'Solution Architect', 'Specialist Wintel & Cloud', 'Software Engineer', 'Senior Cloud Partner Manager', 'Lead  Senior Cloud Engineer', 'Cloud Native Java Developer', 'Oracle Financial Lead- EBS Cloud', 'Data Technology Engineer', 'Sr. Manager Cloud Solution Architect', 'Architect Salesforce Marketing Cloud', 'Partner Sales Manager –Cloud & Tech Alliances – ASEAN', 'Operations Manager Cloud and System Ops', 'Cloud Native Evangelist -', 'Senior Project Manager IT – Cloud Platform', 'Site Reliability Engineer. Cloud Vice President', 'Associate Consultant', 'Sales Development intern', 'Consulting Analyst', 'Oracle Service Cloud Consultant', 'Cloud Network Security Engineer', 'Senior Sales Specialist Hybrid Cloud and Infrastructure Services', 'Cloud DevOps Engineer', 'Cloud and IT Transformation - Cloud Strategy Manager', 'DevOps Consultant', 'Data Engineer', 'Junior Cloud Engineer', 'Cloud Technical Solution Architect Asia Pacific', 'Quant Developer Crypto Trading technologies - SG', 'Security Infra - Cloud & System Engineer', 'Cloud Devops Engineer', 'Head of Industry Solutions and Architecture Google Cloud', 'Business Analyst', 'Cyber & Forensics Consulting  - Senior Associate', 'Senior Manager – Business Development – New Cloud Offering  - Opportunity for Working Remotely', 'SAP Cloud Solution Architect', 'Java Technical Architect', 'DevOps Engineer', 'Cloud Platform DevOps Engineer', 'Data Center Operations Trainee',  ...

# %%
# remove fields in brackets, numbers, hashatags
def clean_regex(x, company_list, country_list):
    x = re.sub('\\(.+?\\)', "", str(x))   # remove anything in ()
    x = re.sub('\\[.+?\\]', "", str(x))   # remove anything in []
    x = re.sub(r'\w*\d\w*','', str(x))    # remove number
    x = re.sub(r'[\S]+#[\S]+','',str(x))  # remove hashtags
    x = re.sub(r'#[\S]+','', str(x))      # remove hashtags 
    
    for word in x: 
        if word in company_list:
            x = x.split('|')[-1]
        else:
            x = re.sub('\|.*$',"", x)
            
    x = x.replace(',','')                 # remove commas
    x = x.replace('/','')                 # remove slash
    
    
    for word in x.split(): 
        if word in country_list:
            x = x.replace(word,'')   
            
    return x.strip()

# %%
country_list = ['Afghanistan', 'Aland Islands', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia, Plurinational State of', 'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Botswana', 'Bouvet Island', 'Brazil', 'British Indian Ocean Territory', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo', 'Congo, The Democratic Republic of the', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire", 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana', 'French Polynesia', 'French Southern Territories', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Heard Island and McDonald Islands', 'Holy See (Vatican City State)', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran, Islamic Republic of', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', "Korea, Democratic People's Republic of", 'Korea, Republic of', 'Kuwait', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Macedonia, Republic of', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia, Federated States of', 'Moldova, Republic of', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island', 'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Palestinian Territory, Occupied', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Réunion', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Barthélemy', 'Saint Helena, Ascension and Tristan da Cunha', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Martin (French part)', 'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa', 'South Georgia and the South Sandwich Islands', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'South Sudan', 'Svalbard and Jan Mayen', 'Swaziland', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Taiwan, Province of China', 'Tajikistan', 'Tanzania, United Republic of', 'Thailand', 'Timor-Leste', 'Togo', 'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'United States Minor Outlying Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela, Bolivarian Republic of', 'Viet Nam', 'Virgin Islands, British', 'Virgin Islands, U.S.', 'Wallis and Futuna', 'Yemen', 'Zambia', 'Zimbabwe']
company_list = ['DigitalBCG', 'Essence' ]

df = df.apply(lambda x: clean_regex(str(x), company_list, country_list))
df
# Out:
# 0                                Technical Content Writer
# 1                            Software Engineering  Intern
# 2                                     Expansion Associate
# 3                                         Cloud Architect
# 4                           Cloud Infrastructure Engineer
#                               ...
# 6945                         Digital Solutions Consultant
# 6946     Senior Infrastructure Engineer Endpoint Security
# 6947    Agile Software Engineer Intern - Smart Buildin...
# 6948    Associate Software Engineer Secured Infrastruc...
# 6949               Sr. Site Reliability Engineer - Hadoop
# Length: 6950, dtype: object

# %%
# Convert df to DataFrame
df = df.to_frame(name='job_title')

# %% [markdown]
# # Change to vector

# %%
vec = TfidfVectorizer(stop_words="english")
vec.fit(df['job_title'].values) # change to skills
features = vec.transform(df['job_title'].values)

# %%
vec.get_feature_names()
# Out:
# ['abap',
#  'abm',
#  'academy',
#  'acceleration',
#  'accelerator',
#  'access',
#  'account',
#  'accountant',
#  'accounting',
#  'accounts',
#  'accurics',
#  'ace',
#  'acquisition',
#  'acquisitions',
#  'action',
#  'activation',
#  'active',
#  'ad',
#  'adm',
#  'admin',
#  'administration',
#  'administrative',
#  'administrator',
#  'administrators',
#  'adminitrator',
#  'admiralty',
#  'adobe',
#  'adoption',
#  'ads',
#  'adtech',
#  'advanced',
#  'advancement',
#  'advertising',
#  'adviser',
#  'advisor',
#  'advisorsenior',
#  'advisory',
#  'advocacy',
#  'advocate',
#  'aem',
#  'aerospace',
#  'affairs',
#  'affinity',
#  'agency',
#  'agent',
#  'agent_fte',
#  'agile',
#  'agility',
#  'ai',
#  'aimachine',
#  'aiml',
#  'aio',
#  'aiops',
#  'airport',
#  'aladdin',
#  'alarm',
#  'algorithm',
#  'algorithms',
#  'alliance',
#  'alliances',
#  'almachine',
#  'amazon',
#  'amda',
#  'amea',
#  'aml',
#  'analist',
#  'analog',
#  'analysis',
#  'analyst',
#  'analystassistant',
#  'analystbusiness',
#  'analystconsultant',
#  'analystspecialist',
#  'analysttrade',
#  'analyt',
#  'analytic',
#  'analytics',
#  'anchor',
#  'android',
#  'androidios',
#  'angular',
#  'anlayst',
#  'ans',
#  'ansible',
#  'anz',
#  'ap',
#  'apac',
#  'apcj',
#  'apec',
#  'apex',
#  'api',
#  'apim',
#  'apiweb',
#  'apj',
#  'apjc',
#  'app',
#  'appdynamics',
#  'appl',
#  'application',
#  'applications',
#  'applicationsolution',
#  'applied',
#  'apprentice',
#  'apprenticeship',
#  'apps',
#  'arch',
#  'architech',
#  'architect',
#  'architect_',
#  'architect_financial',
#  'architectconsultant',
#  'architects',
#  'architecttech',
#  'architecture',
#  'area',
#  'arm',
#  'art',
#  'artc',
#  'artificial',
#  'artist',
#  'asean',
#  'aseanzk',
#  'asia',
#  'asiapac',
#  'asic',
#  'asp',
#  'aspiring',
#  'asscoate',
#  'assessment',
#  'asset',
#  'assets',
#  'assistant',
#  'assistantexecutive',
#  'assistants',
#  'assoc',
#  'associate',
#  'associateassistant',
#  'associatedesign',
#  'associatelead',
#  'associatemanager',
#  'associates',
#  'associatesenior',
#  'associatevp',
#  'assortment',
#  'asst',
#  'assurance',
#  'athena',
#  'attack',
#  'attraction',
#  'attractive',
#  'audit',
#  'auditor',
#  'australia',
#  'authority',
#  'auto',
#  'autodesk',
#  'automation',
#  'automotive',
#  'autonomous',
#  'autosys',
#  'autumn',
#  'av',
#  'availability',
#  'avaloq',
#  'avp',
#  'avpsales',
#  'avpvp',
#  'awm',
#  'aws',
#  'awsazure',
#  'axway',
#  'ayf',
#  'azure',
#  'ba',
#  'backend',
#  'backlog',
#  'backup',
#  'bahasa',
#  'bank',
#  'banking',
#  'banklync',
#  'basis',
#  'bd',
#  'bdaccounts',
#  'bdm',
#  'beauty',
#  'belt',
#  'bfsi',
#  'bi',
#  'bid',
#  'big',
#  'bigdata',
#  'billing',
#  'bim',
#  'bioinformatician',
#  'bioinformatics',
#  'biological',
#  'bis',
#  'biz',
#  'black',
#  'blockchain',
#  'blockchaindlt',
#  'bloomberg',
#  'blue',
#  'bobj',
#  'boomi',
#  'boon',
#  'box',
#  'bpi',
#  'branch',
#  'brand',
#  'brands',
#  'broadband',
#  'broadcast',
#  'brokerage',
#  'bsa',
#  'bssoss',
#  'bu',
#  'build',
#  'builders',
#  'building',
#  'bukit',
#  'bus',
#  'business',
#  'businesses',
#  'buy',
#  'buyer',
#  'bw',
#  'bydesign',
#  'bytehouse',
#  'byteplus',
#  'cad',
#  'campaign',
#  'campaigns',
#  'campus',
#  'canonical',
#  'capability',
#  'capacity',
#  'capgemini',
#  'capital',
#  'capture',
#  'capturebusiness',
#  'card',
#  'cards',
#  'cardspal',
#  'care',
#  'career',
#  'careerists',
#  'careerpathways',
#  'carrier',
#  'cart',
#  'casa',
#  'case',
#  'cash',
#  'category',
#  'cbd',
#  'cbi',
#  'cbidcm',
#  'cc',
#  'ccib',
#  'cclaw',
#  'cdo',
#  'cds',
#  'ce',
#  'center',
#  'central',
#  'centre',
#  'ceo',
#  'certification',
#  'ces',
#  'cfin',
#  'cfo',
#  'chai',
#  'chain',
#  'chairman',
#  'champion',
#  'change',
#  'changi',
#  'channel',
#  'channels',
#  'chapter',
#  'charging',
#  'chartered',
#  'chat',
#  'chatbot',
#  'chee',
#  'chef',
#  'chemical',
#  'chief',
#  'childcare',
#  'chinese',
#  'ci',
#  'ciam',
#  'cib',
#  'cicd',
#  'cicddevsecops',
#  'cics',
#  'cid',
#  'circular',
#  'cirt',
#  'cisco',
#  'ciso',
#  'cissp',
#  'cit',
#  'citbci',
#  'civil',
#  'claims',
#  'clearing',
#  'client',
#  'clinical',
#  'cloud',
#  'cloudaiml',
#  'cloudblue',
#  'clouddevops',
#  'cloudops',
#  'clouds',
#  'cloudsense',
#  'cls',
#  'clt',
#  'cluster',
#  'cmi',
#  'cmp',
#  'coach',
#  'code',
#  'codex',
#  'coding',
#  'coe',
#  'cognizant',
#  'collaboration',
#  'collection',
#  'command',
#  'commerce',
#  'commercial',
#  'commissioning',
#  'commissions',
#  'commodities',
#  'commodity',
#  'comms',
#  'communication',
#  'communications',
#  'community',
#  'company',
#  'compensation',
#  'complex',
#  'complexity',
#  'compliance',
#  'component',
#  'composer',
#  'compositor',
#  'computational',
#  'compute',
#  'computer',
#  'computing',
#  'concepts',
#  'concur',
#  'conduct',
#  'conferencing',
#  'configuration',
#  'conglomerate',
#  'connect',
#  'connectivity',
#  'construction',
#  'consultant',
#  'consultant_compute',
#  'consultantmanager',
#  'consultants',
#  'consultantsenior',
#  'consulting',
#  'consumer',
#  'consumption',
#  'contact',
#  'container',
#  'containerization',
#  'containers',
#  'content',
#  'continous',
#  'continuity',
#  'continuous',
#  'contract',
#  'contracting',
#  'contractor',
#  'contracts',
#  'control',
#  'controller',
#  'controlplane',
#  'controls',
#  'converged',
#  'conversational',
#  'conversion',
#  'convertable',
#  'cook',
#  'cooling',
#  'coordination',
#  'coordinator',
#  'coordinator_',
#  'copenhagen',
#  'copywriter',
#  'corda',
#  'core',
#  'corp',
#  'corporate',
#  'cortex',
#  'cost',
#  'costing',
#  'couchbase',
#  'counsel',
#  'counsellor',
#  'counter',
#  'coupa',
#  'coverage',
#  'cpi',
#  'creation',
#  'creative',
#  'creator',
#  'creatordigital',
#  'credit',
#  'cresa',
#  'crisis',
#  'crisp',
#  'critical',
#  'crm',
#  'cross',
#  'crossover',
#  'crypto',
#  'cryptocurrency',
#  'cryptographycybersecurity',
#  'cto',
#  'cum',
#  'custom',
#  'customer',
#  'customers',
#  'customertechnical',
#  'cutover',
#  'cx',
#  'cxo',
#  'cyber',
#  'cyberdefence',
#  'cybersecurity',
#  'cycle',
#  'daas',
#  'dat',
#  'data',
#  'dataai',
#  'database',
#  'databases',
#  'datacenter',
#  'datamarts',
#  'dataops',
#  'dataservicenowblockchain',
#  'datatech',
#  'datawarehouse',
#  'datawarehousing',
#  'days',
#  'db',
#  'dba',
#  'dc',
#  'dcda',
#  'dceo',
#  'dcws',
#  'ddi',
#  'deal',
#  'dean',
#  'debug',
#  'decom',
#  'decsecops',
#  'dedicated',
#  'deep',
#  'defence',
#  'defense',
#  'defined',
#  'deliveries',
#  'delivery',
#  'dell',
#  'demand',
#  'dep',
#  'department',
#  'deployment',
#  'deputy',
#  'deputyassistant',
#  'derivative',
#  'design',
#  'designer',
#  'designerdeveloper',
#  'designersr',
#  'desk',
#  'deskside',
#  'desktop',
#  'desktopapplication',
#  'detection',
#  'dev',
#  'develop',
#  'developer',
#  'developeradobe',
#  'developerconsultant',
#  'developerdevsecops',
#  'developerengineer',
#  'developers',
#  'developersoftware',
#  'developerspecialist',
#  'development',
#  'devloper',
#  'devops',
#  'devopssre',
#  'devsecops',
#  'devsevops',
#  'devt',
#  'dfs',
#  'di',
#  'diagnosis',
#  'digibank',
#  'digital',
#  'digitalbcg',
#  'dircetor',
#  'direct',
#  'director',
#  'directorsvp',
#  'directory',
#  'directr',
#  'disaster',
#  'disbursement',
#  'discovery',
#  'display',
#  'displays',
#  'disputes',
#  'distributed',
#  'distribution',
#  'distributor',
#  'distributors',
#  'district',
#  'div',
#  'diversity',
#  'division',
#  'django',
#  'dlp',
#  'dmlt',
#  'dms',
#  'dna',
#  'dnb',
#  'dnbisv',
#  'docker',
#  'document',
#  'documentdb',
#  'documentum',
#  'domain',
#  'dot',
#  'dotnet',
#  'dp',
#  'dr',
#  'dro',
#  'dtc',
#  'duty',
#  'dx',
#  'dynamic',
#  'dynamics',
#  'early',
#  'easements',
#  'easm',
#  'easre',
#  'east',
#  'ebc',
#  'ebs',
#  'ebscloud',
#  'ecm',
#  'ecommerce',
#  'economic',
#  'economics',
#  'ecosystem',
#  'edge',
#  'edgeconnect',
#  'editor',
#  'edm',
#  'edms',
#  'edstart',
#  'edtech',
#  'education',
#  'eemea',
#  'effectiveness',
#  'ehs',
#  'eibu',
#  'ekos',
#  'elastic',
#  'electrical',
#  'electronic',
#  'electronics',
#  'elite',
#  'elk',
#  'em',
#  'email',
#  'embedded',
#  'emc',
#  'emeaapac',
#  'emerging',
#  'employee',
#  'enablement',
#  'end',
#  'endpoint',
#  'energy',
#  'eng',
#  'engagement',
#  'engagements',
#  'engg',
#  'engineer',
#  'engineerarchitect',
#  'engineerassistant',
#  'engineerconsultant',
#  'engineerdata',
#  'engineerdeveloper',
#  'engineerdevops',
#  'engineerfull',
#  'engineering',
#  'engineerintegrator',
#  'engineermanager',
#  'engineers',
#  'engineersenior',
#  'engineersoftware',
#  'engineertechnician',
#  'enginer',
#  'english',
#  'engr',
#  'engring',
#  'enhancement',
#  'ent',
#  'enterprise',
#  'entry',
#  'environment',
#  'epic',
#  'equities',
#  'equity',
#  'erp',
#  'escalation',
#  'escalations',
#  'esd',
#  'essbase',
#  'essence',
#  'estate',
#  'ethical',
#  'etl',
#  'etrading',
#  'euc',
#  'europe',
#  'evaluations',
#  'evangelist',
#  'event',
#  'evf',
#  'excellence',
#  'exchange',
#  'exec',
#  'execution',
#  'executive',
#  'executiveassistant',
#  'executivesenior',
#  'expansion',
#  'experience',
#  'experienced',
#  'experiences',
#  'experiential',
#  'experimental',
#  'experimentation',
#  'experiments',
#  'expert',
#  'expertise',
#  'export',
#  'expression',
#  'external',
#  'fa',
#  'facilities',
#  'facility',
#  'facing',
#  'factors',
#  'faculty',
#  'failure',
#  'fas',
#  'fast',
#  'fasttrack',
#  'fdc',
#  'federated',
#  'fellow',
#  'fellowengineer',
#  'fi',
#  'ficc',
#  'fico',
#  'field',
#  'finacle',
#  'finance',
#  'financial',
#  'financials',
#  'financing',
#  'finops',
#  'fintech',
#  'firebase',
#  'firm',
#  'firmware',
#  'fixed',
#  'fleet',
#  'floor',
#  'flow',
#  'flowable',
#  'flutter',
#  'fm',
#  'fmp',
#  'focused',
#  'forensic',
#  'forensics',
#  'foundation',
#  'foundry',
#  'frameworks',
#  'franchise',
#  'fraud',
#  'fresh',
#  'freshjunior',
#  'frontend',
#  'frontendbackend',
#  'fsbu',
#  'fsi',
#  'ftc',
#  'fullstack',
#  'function',
#  'functional',
#  'functions',
#  'fund',
#  'fuse',
#  'fusion',
#  'futures',
#  'fvp',
#  'fx',
#  'gam',
#  'game',
#  'gamefrontend',
#  'games',
#  'gaming',
#  'gateway',
#  'gbb',
#  'gbt',
#  'gcc',
#  'gcp',
#  'gen',
#  'general',
#  'generation',
#  'geo',
#  'gfg',
#  'gfs',
#  'giant',
#  'gic',
#  'gis',
#  'global',
#  'globalization',
#  'gm',
#  'golang',
#  'gold',
#  'google',
#  'goto',
#  'governance',
#  'government',
#  'govtech',
#  'gps',
#  'grab',
#  'grabkitchen',
#  'grabx',
#  'grad',
#  'grads',
#  'graduate',
#  'graduates',
#  'graph',
#  'graphic',
#  'graviton',
#  'grc',
#  'greater',
#  'greenfield',
#  'gross',
#  'group',
#  'growing',
#  'growth',
#  'gsi',
#  'gsoc',
#  'gtech',
#  'gtm',
#  'gtpc',
#  'gts',
#  'gtsais',
#  'guest',
#  'guide',
#  'guided',
#  'guild',
#  'gwh',
#  'hacker',
#  'hadoop',
#  'hana',
#  'happiness',
#  'hardware',
#  'hare',
#  'hbo',
#  'hcm',
#  'hd',
#  'head',
#  'headassistant',
#  'headcounts',
#  'headend',
#  'health',
#  'healthcare',
#  'healthtechs',
#  'hedge',
#  'helpdesk',
#  'helpdeskapplication',
#  'helper',
#  'het',
#  'hh',
#  'hi',
#  'high',
#  'higher',
#  'hindi',
#  'hire',
#  'hiring',
#  'hong',
#  'host',
#  'hosting',
#  'hour',
#  'hpc',
#  'hq',
#  'hr',
#  'hrfa',
#  'hris',
#  'hrms',
#  'hse',
#  'hub',
#  'human',
#  'humio',
#  'hunter',
#  'hunteranalyst',
#  'hunting',
#  'hybrid',
#  'hybris',
#  'hypervisor',
#  'ia',
#  'iaas',
#  'iam',
#  'iampam',
#  'iams',
#  'ibm',
#  'ibp',
#  'ic',
#  'icg',
#  'icomm',
#  'ics',
#  'ict',
#  'id',
#  'idd',
#  'identity',
#  'idms',
#  'ids',
#  'ihpc',
#  'ii',
#  'iii',
#  'iits',
#  'ik',
#  'illustrator',
#  'image',
#  'imda',
#  'immediate',
#  'immediately',
#  'immigration',
#  'impact',
#  'implementation',
#  'inbound',
#  'incident',
#  'income',
#  'index',
#  'indirect',
#  'indonesian',
#  'indonesiavietnamthailand',
#  'industrial',
#  'industries',
#  'industry',
#  'info',
#  'infocomm',
#  'informatica',
#  'informatics',
#  'information',
#  'infosecurity',
#  'infra',
#  'infrastructure',
#  'initiative',
#  'initiatives',
#  'inline',
#  'innovating',
#  'innovation',
#  'innovations',
#  'innovative',
#  'inside',
#  'insights',
#  'inspection',
#  'institutional',
#  'instructor',
#  'insurance',
#  'int',
#  'intake',
#  'integrated',
#  'integration',
#  'integrations',
#  'integrator',
#  'integrators',
#  'integrity',
#  'intelligence',
#  'interaction',
#  'interface',
#  'interior',
#  'intermediate',
#  'intern',
#  'internal',
#  'international',
#  'internet',
#  'interns',
#  'internship',
#  'internships',
#  'interrn',
#  'intune',
#  'investigator',
#  'investment',
#  'io',
#  'ios',
#  'iot',
#  'ip',
#  'isbn',
#  'iso',
#  'issuance',
#  'isv',
#  'isvs',
#  'ite',
#  'itsm',
#  'itt',
#  'itx',
#  'iv',
#  'ivr',
#  'ivvq',
#  'japac',
#  'japanese',
#  'jason',
#  'java',
#  'javan',
#  'javankotlin',
#  'javascript',
#  'jd',
#  'jdi',
#  'jenkins',
#  'jo',
#  'job',
#  'jobs',
#  'join',
#  'journey',
#  'jr',
#  'js',
#  'juju',
#  'junior',
#  'juniorsenior',
#  'jurong',
#  'jyk',
#  'kafka',
#  'keat',
#  'kernel',
#  'key',
#  'kids',
#  'kim',
#  'kinaxis',
#  'kitchen',
#  'kitchens',
#  'knowledge',
#  'kong',
#  'korea',
#  'korean',
#  'kotlin',
#  'kr',
#  'kubernetes',
#  'kyndryl',
#  'lab',
#  'laboratory',
#  'labs',
#  'lake',
#  'lan',
#  'land',
#  'landed',
#  'language',
#  'languages',
#  'lark',
#  'laws',
#  'lay',
#  'layer',
#  'layout',
#  'lead',
#  'leadarchitect',
#  'leadcloud',
#  'leaddevops',
#  'leader',
#  'leaders',
#  'leadership',
#  'leadmanager',
#  'leadprincipal',
#  'leadsenior',
#  'learning',
#  'learningbig',
#  'lecturer',
#  'lecturerlecturer',
#  ...]

# %% [markdown]
# ## Creating model

# %%
cls = MiniBatchKMeans(n_clusters=10, random_state=random_state)
cls.fit(features)
# Out:
# MiniBatchKMeans(n_clusters=10, random_state=0)

# %%
# predict cluster labels for new dataset
cls.predict(features)

# to get cluster labels for the dataset used while
# training the model (used for models that does not
# support prediction on new dataset).
cls.labels_
# Out:
# array([8, 8, 8, ..., 7, 7, 7])

# %%
df['Cluster'] = cls.labels_

# %%
df
# Out:
#                                               job_title  Cluster
# 0                              Technical Content Writer        8
# 1                          Software Engineering  Intern        8
# 2                                   Expansion Associate        8
# 3                                       Cloud Architect        9
# 4                         Cloud Infrastructure Engineer        7
# ...                                                 ...      ...
# 6945                       Digital Solutions Consultant        6
# 6946   Senior Infrastructure Engineer Endpoint Security        2
# 6947  Agile Software Engineer Intern - Smart Buildin...        7
# 6948  Associate Software Engineer Secured Infrastruc...        7
# 6949             Sr. Site Reliability Engineer - Hadoop        7
#
# [6950 rows x 2 columns]

# %% [markdown]
# ## Evaluation
# - best value is 1 and worst value is -1
# - values near 0 indicates overlapping clusters

# %%
from sklearn.metrics import silhouette_score
silhouette_score(features, labels=cls.predict(features))
# Out:
# 0.041258868984515

# %%
cluster_list = df.groupby('Cluster')['job_title'].apply(list)
cluster_list
# Out:
# Cluster
# 0    [HR Business Partner, Business Program Manager...
# 1    [Software Engineer Intern, Software Engineer -...
# 2    [Lead  Senior Cloud Engineer, Senior Cybersecu...
# 3    [Segment Marketing Manager, Technical Account ...
# 4    [Cloud Native Developer - Computing Platform, ...
# 5    [Data Analyst Data Management Governance & Dat...
# 6    [Customer Engineering Manager Digital Native C...
# 7    [Cloud Infrastructure Engineer, Cloud Storage ...
# 8    [Technical Content Writer, Software Engineerin...
# 9    [Cloud Architect, Associate Solution Sales Dir...
# Name: job_title, dtype: object

# %%
for i in cluster_list.index:
    top5 = pd.Series(cluster_list[i]).value_counts().head(5)
    top5_words = list(top5.index)
    print(f'Cluster {i}:')
    print(top5_words)
    print()
# Out:
# Cluster 0:
# ['Business Analyst', 'Business Development Manager', 'Business Development Representative', 'Senior Business Analyst', 'Business Development Representatives  - Join our Talent Network!']
#
# Cluster 1:
# ['Software Engineer', 'Senior Software Engineer', 'Software Engineer  Cloud Infrastructure', 'Software Engineer  - Cloud Infrastructure', '- Software Engineer']
#
# Cluster 2:
# ['Senior DevOps Engineer', 'Senior System Engineer', 'Senior Site Reliability Engineer', 'Senior Engineer', 'Senior Systems Engineer']
#
# Cluster 3:
# ['Project Manager', 'Product Manager', 'Manager', 'Sales Manager', 'IT Project Manager']
#
# Cluster 4:
# ['Software Developer', 'Full Stack Developer', 'Java Developer', 'Senior Full Stack Developer', 'Application Developer']
#
# Cluster 5:
# ['System Analyst', 'Senior System Analyst', 'Data Analyst', 'Security Analyst', 'SOC Advanced Cyber Defense Analyst']
#
# Cluster 6:
# ['Digital Business Analyst', 'Digital Marketing Manager', 'Digital Consultant', 'Digital Marketing Specialist', 'Digital and Application Innovation Regional Lead  - Customer Success']
#
# Cluster 7:
# ['DevOps Engineer', 'Data Engineer', 'Cloud Engineer', 'Network Engineer', 'System Engineer']
#
# Cluster 8:
# ['Consultant', 'Research Associate', 'Pre-Sales Consultant', 'Enterprise Account Executive', 'System Administrator']
#
# Cluster 9:
# ['Solution Architect', 'Solutions Architect', 'Enterprise Architect', 'Cloud Solution Architect', 'Software Architect']

# %% [markdown]
# ## Visualisation

# %%
# reduce the features to 2D
pca = PCA(n_components=2, random_state=random_state)
reduced_features = pca.fit_transform(features.toarray())

# reduce the cluster centers to 2D
reduced_cluster_centers = pca.transform(cls.cluster_centers_)

# %%
plt.scatter(reduced_features[:,0], reduced_features[:,1], c=cls.predict(features))
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='b')

# %% [markdown]
# ### Imports and Reading most updated data

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("../data/cleaned/filtered_job_roles.csv", index_col=0)
df.head(1)
# Out:
#    Unnamed: 0                job_title company_name   job_type tech_stack  \
# 0           0  Senior Python Developer         Citi  permanent        NaN
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
#
#    upper_salary  lower_year  upper_year  \
# 0           NaN         NaN         NaN
#
#                                 extracted_tech_stack all_tech_stack  \
# 0  {'JavaScript', 'SQL', 'REST', 'big data', 'Haz...          set()
#
#                                     cleaned_job_desc             Cluster
# 0  job description      job purpose   we are look...  Software Developer

# %% [markdown]
# ### Extracting Education Level and Field of Study from Job Postings

# %%
level_dict = {
    "PhD": ["phd", "doctor", "doctorate"],
    "Master's": ["masters degree", "master", "master's degree", " ms "],
    "Bachelor's": ["bachelor's degree", "bachelor degree", "bachelor's", "bachelor", "degree", "bsc", " bs ", "college", "university"],
    "Diploma": ["diploma"]
}

field_dict = {
    "Relevant Field": ["related", "relevant", "equivalent", "related field", "related discipline", "technical field", "related area"],
    "Computer Science": ["computer science", " cs ", "comp sci", "com sci", "computing"],
    "Mathematics": ["mathematics", "math"],
    "Information Technology": ["information technology", " it ", "technology", "information systems", "digital technologies"],
    "Computer/Software Engineering": ["computer engineering", "software engineering"],
    "Electrical and Electronics Engineering": ["electrical and electronics engineering", "bsee", "electrical engineering", "electronics engineering"],
    "Physics": ["physics"],
    "Business": ["business", "MBA"]
}

# %%
# Initialise empty rows
df['education_level'] = df.apply(lambda x: set(), axis=1)
df['education_field'] = df.apply(lambda x: set(), axis=1)

# %%
# Iterate through level dictionary and level variations
for level, level_list in level_dict.items():
    for level_variation in level_list:
        # Iterate through dataframe
        for i, row in df.iterrows():
            # If description is a string, and contains level_variation, append level
            if type(row['cleaned_job_desc']) == str and re.search(level_variation, row['cleaned_job_desc']) is not None:
                df.at[i, "education_level"].add(level)
                # Iterate through matches of level_variations
                for match in re.finditer(level_variation, row['cleaned_job_desc']):
                    # Iterate through field dictionary and field variations
                    for field, field_list in field_dict.items():
                        for field_variation in field_list:
                            # If field_variation within 100 characters of match, append field
                            if field_variation in row['cleaned_job_desc'][match.start():match.end()+100]:
                                df.at[i, "education_field"].add(field)
df
# Out:
#        Unnamed: 0                                       job_title  \
# 0               0                         Senior Python Developer
# 1               1  Senior Partner Solutions Architect (Microsoft)
# 7               7                     Cloud Engineer (Automation)
# 8               8                     Cloud Engineer (Automation)
# 9               9        Senior Software and Automation Architect
# ...           ...                                             ...
# 11442        2894       Enterprise Solutions Engineer (Singapore)
# 11443        2896                                 DevOps Engineer
# 11444        2897                                 DevOps Engineer
# 11445        2898                                 DevOps Engineer
# 11446        2899                               Software Engineer
#
#                                        company_name   job_type  \
# 0                                              Citi  permanent
# 1                                            Amazon  permanent
# 7                          Recruit Expert Pte. Ltd.  permanent
# 8                          Recruit Expert Pte. Ltd.  permanent
# 9      Cisco International Limited Singapore Branch  permanent
# ...                                             ...        ...
# 11442                                     Confluent  Permanent
# 11443                                          2C2P  Permanent
# 11444                                       FINXFLO  Permanent
# 11445                                      Quilt.AI  Permanent
# 11446                      Zoku Integrated Commerce  Permanent
#
#                                               tech_stack  \
# 0                                                    NaN
# 1                                                    NaN
# 7      ['Puppet', 'Cloud Applications', 'Cloud Securi...
# 8      ['Puppet', 'Cloud Applications', 'Cloud Securi...
# 9      ['Kubernetes', 'Cloud Computing', 'JIRA', 'Pyt...
# ...                                                  ...
# 11442  ['ETL', 'MessageQueue', 'essageQueue', 'Apache...
# 11443  ['GitLab', 'HTTP', 'UDP', 'TCP', 'ShellScript'...
# 11444  ['Strategy', 'ShellScript', 'CI', 'Shell', 'UN...
# 11445  ['Next.js', 'Docker', 'Cloudflare', 'DockerSwa...
# 11446  ['API', 'Magento', 'CI', 'DOM', 'Node.js', 'No...
#
#                                                 job_desc  \
# 0      Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1      Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 7      In-charge of the design, deployment, installat...
# 8      In-charge of the design, deployment, installat...
# 9      What You'll Do\r\nCisco Customer Experience (C...
# ...                                                  ...
# 11442  We’re looking for self-motivated team members ...
# 11443  2C2P is looking for a .NET DevOps Engineer to ...
# 11444  Alpha Stone Capital is looking for an amazing ...
# 11445  As part of a growing team consisting of ML exp...
# 11446  We are hiring software engineers with expertis...
#
#                                         industry date_posted  \
# 0      ['Banking/Accounting/Financial Services']  2022-02-18
# 1                        ['Internet/E-commerce']  2022-02-18
# 7                                      ['Other']  2022-02-19
# 8                                      ['Other']  2022-03-14
# 9                                      ['Other']  2022-02-19
# ...                                          ...         ...
# 11442                                        NaN  2022-01-11
# 11443                                        NaN  2022-01-11
# 11444                                        NaN  2022-01-11
# 11445                                        NaN  2022-01-11
# 11446                                        NaN  2022-01-11
#
#                                                      url     source  \
# 0      https://www.monster.com.sg/seeker/job-details?...    monster
# 1      https://www.monster.com.sg/seeker/job-details?...    monster
# 7      https://www.monster.com.sg/seeker/job-details?...    monster
# 8      https://www.monster.com.sg/seeker/job-details?...    monster
# 9      https://www.monster.com.sg/seeker/job-details?...    monster
# ...                                                  ...        ...
# 11442              https://www.nodeflair.com//jobs/46158  nodeflair
# 11443              https://www.nodeflair.com//jobs/46156  nodeflair
# 11444              https://www.nodeflair.com//jobs/46153  nodeflair
# 11445              https://www.nodeflair.com//jobs/46151  nodeflair
# 11446              https://www.nodeflair.com//jobs/46149  nodeflair
#
#        lower_salary  upper_salary  lower_year  upper_year  \
# 0               NaN           NaN         NaN         NaN
# 1               NaN           NaN         NaN         NaN
# 7           48000.0       66000.0         2.0         5.0
# 8           48000.0       60000.0         2.0         5.0
# 9          108000.0      180000.0        10.0        15.0
# ...             ...           ...         ...         ...
# 11442           NaN           NaN         NaN         NaN
# 11443        7000.0       10000.0         NaN         3.0
# 11444           NaN           NaN         NaN         NaN
# 11445           NaN           NaN         NaN         3.0
# 11446           NaN           NaN         NaN         3.0
#
#                                     extracted_tech_stack  \
# 0      {'JavaScript', 'SQL', 'REST', 'big data', 'Haz...
# 1      {'Stack', 'Caching', 'Azure', 'Load Balencers'...
# 7      {'IT', 'upgrades', 'R1326740', 'Ansible', 'fix...
# 8      {'IT', 'upgrades', 'R1326740', 'Ansible', 'fix...
# 9      {'Industry Cloud', 'Artifactory', 'YANG', 'Cus...
# ...                                                  ...
# 11442  {'California', 'beliefs', 'Inc', 'disk', 'Apac...
# 11443  {'TCP', 'Bamboo CI', 'qualifications &', 'HTTP...
# 11444  {'Secure Infrastructure', 'Jenkins', 'IaC', 'T...
# 11445  {'AWS CodePipeline', 'release', 'Jenkins', 'Ia...
# 11446  {'JavaScript', 'SQL', 'Shopify', 'NodeJS', 'Re...
#
#                                           all_tech_stack  \
# 0                                                  set()
# 1                                                  set()
# 7      {' Cloud Computing', ' Cloud-based', ' Cloud S...
# 8      {' Cloud Computing', ' Cloud-based', ' Cloud S...
# 9      {'Cisco', 'CircleCI', 'CI', 'Orchestration', '...
# ...                                                  ...
# 11442  {' essageQueue', ' Apache', 'California', 'bel...
# 11443  {' ELK', ' Jenkins', 'TCP', 'Code', ' .NET', '...
# 11444  {' Jenkins', ' JavaScript', ' Terraform', 'Sec...
# 11445  {' Jenkins', ' Container', 'AWS CodePipeline',...
# 11446  {'JavaScript', ' JavaScript', 'SQL', ' SQL', '...
#
#                                         cleaned_job_desc              Cluster  \
# 0      job description      job purpose   we are look...   Software Developer
# 1      job description    job summary  description  d...  Solutions Architect
# 7      in charge of the design  deployment  installat...       Cloud Engineer
# 8      in charge of the design  deployment  installat...       Cloud Engineer
# 9      what you ll do  cisco customer experience  cx ...  Solutions Architect
# ...                                                  ...                  ...
# 11442  we re looking for self motivated team members ...  Solutions Architect
# 11443   is looking for a  net devops engineer to join...      Devops Engineer
# 11444  alpha stone capital is looking for an amazing ...      Devops Engineer
# 11445  as part of a growing team consisting of ml exp...      Devops Engineer
# 11446  we are hiring software engineers with expertis...    Software Engineer
#
#               education_level  \
# 0                          {}
# 1                  {Master's}
# 7      {Master's, Bachelor's}
# 8      {Master's, Bachelor's}
# 9                          {}
# ...                       ...
# 11442            {Bachelor's}
# 11443                      {}
# 11444  {Master's, Bachelor's}
# 11445            {Bachelor's}
# 11446            {Bachelor's}
#
#                                          education_field
# 0                                                     {}
# 1                                                     {}
# 7      {Computer Science, Information Technology, Rel...
# 8      {Computer Science, Information Technology, Rel...
# 9                                                     {}
# ...                                                  ...
# 11442                                 {Computer Science}
# 11443                                                 {}
# 11444                 {Computer Science, Relevant Field}
# 11445  {Computer Science, Computer/Software Engineeri...
# 11446                 {Computer Science, Relevant Field}
#
# [5405 rows x 20 columns]

# %%
df.drop(columns=["Unnamed: 0", "extracted_tech_stack"], inplace=True)
df.rename(columns={"Cluster":"cluster"}, inplace=True)
df.head()
# Out:
#                                         job_title  \
# 0                         Senior Python Developer
# 1  Senior Partner Solutions Architect (Microsoft)
# 7                     Cloud Engineer (Automation)
# 8                     Cloud Engineer (Automation)
# 9        Senior Software and Automation Architect
#
#                                    company_name   job_type  \
# 0                                          Citi  permanent
# 1                                        Amazon  permanent
# 7                      Recruit Expert Pte. Ltd.  permanent
# 8                      Recruit Expert Pte. Ltd.  permanent
# 9  Cisco International Limited Singapore Branch  permanent
#
#                                           tech_stack  \
# 0                                                NaN
# 1                                                NaN
# 7  ['Puppet', 'Cloud Applications', 'Cloud Securi...
# 8  ['Puppet', 'Cloud Applications', 'Cloud Securi...
# 9  ['Kubernetes', 'Cloud Computing', 'JIRA', 'Pyt...
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1  Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 7  In-charge of the design, deployment, installat...
# 8  In-charge of the design, deployment, installat...
# 9  What You'll Do\r\nCisco Customer Experience (C...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
# 1                    ['Internet/E-commerce']  2022-02-18
# 7                                  ['Other']  2022-02-19
# 8                                  ['Other']  2022-03-14
# 9                                  ['Other']  2022-02-19
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 1  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 7  https://www.monster.com.sg/seeker/job-details?...  monster       48000.0
# 8  https://www.monster.com.sg/seeker/job-details?...  monster       48000.0
# 9  https://www.monster.com.sg/seeker/job-details?...  monster      108000.0
#
#    upper_salary  lower_year  upper_year  \
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 7       66000.0         2.0         5.0
# 8       60000.0         2.0         5.0
# 9      180000.0        10.0        15.0
#
#                                       all_tech_stack  \
# 0                                              set()
# 1                                              set()
# 7  {' Cloud Computing', ' Cloud-based', ' Cloud S...
# 8  {' Cloud Computing', ' Cloud-based', ' Cloud S...
# 9  {'Cisco', 'CircleCI', 'CI', 'Orchestration', '...
#
#                                     cleaned_job_desc              cluster  \
# 0  job description      job purpose   we are look...   Software Developer
# 1  job description    job summary  description  d...  Solutions Architect
# 7  in charge of the design  deployment  installat...       Cloud Engineer
# 8  in charge of the design  deployment  installat...       Cloud Engineer
# 9  what you ll do  cisco customer experience  cx ...  Solutions Architect
#
#           education_level                                    education_field
# 0                      {}                                                 {}
# 1              {Master's}                                                 {}
# 7  {Master's, Bachelor's}  {Computer Science, Information Technology, Rel...
# 8  {Master's, Bachelor's}  {Computer Science, Information Technology, Rel...
# 9                      {}                                                 {}

# %% [markdown]
# ### Extracting Cloud Service Provider

# %%
df['aws'] = 0
df['google_cloud'] = 0
df['azure'] = 0

df.head(1)
# Out:
#                  job_title company_name   job_type tech_stack  \
# 0  Senior Python Developer         Citi  permanent        NaN
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
#
#    ...  lower_year  upper_year  all_tech_stack  \
# 0  ...         NaN         NaN           set()
#
#                                     cleaned_job_desc             cluster  \
# 0  job description      job purpose   we are look...  Software Developer
#
#   education_level education_field aws  google_cloud  azure
# 0              {}              {}   0             0      0
#
# [1 rows x 21 columns]

# %%
for i, row in df.iterrows():
    job_desc = str(row['cleaned_job_desc'])
    if "aws" in job_desc or "amazon web services" in job_desc:
        df.at[i,'aws'] = 1
    if "google cloud platform" in job_desc or "gcp" in job_desc:
        df.at[i,'google_cloud'] = 1
    if "azure" in job_desc:
        df.at[i,'azure'] = 1

# %%
df["aws"].value_counts()
# Out:
# 1    2790
# 0    2615
# Name: aws, dtype: int64

# %%
df["google_cloud"].value_counts()
# Out:
# 0    4605
# 1     800
# Name: google_cloud, dtype: int64

# %%
df["azure"].value_counts()
# Out:
# 0    3764
# 1    1641
# Name: azure, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5405 entries, 0 to 11446
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         5405 non-null   object
#  1   company_name      5405 non-null   object
#  2   job_type          5402 non-null   object
#  3   tech_stack        4112 non-null   object
#  4   job_desc          5399 non-null   object
#  5   industry          3867 non-null   object
#  6   date_posted       5046 non-null   object
#  7   url               5405 non-null   object
#  8   source            5405 non-null   object
#  9   lower_salary      2874 non-null   float64
#  10  upper_salary      2874 non-null   float64
#  11  lower_year        3133 non-null   float64
#  12  upper_year        4009 non-null   float64
#  13  all_tech_stack    5405 non-null   object
#  14  cleaned_job_desc  5399 non-null   object
#  15  cluster           5405 non-null   object
#  16  education_level   5405 non-null   object
#  17  education_field   5405 non-null   object
#  18  aws               5405 non-null   int64
#  19  google_cloud      5405 non-null   int64
#  20  azure             5405 non-null   int64
# dtypes: float64(4), int64(3), object(14)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Assign Industry for each Job Posting

# %%
industries_scraped = pd.read_csv("../data/cleaned/Posts_Industry.csv", index_col=0)
industries_scraped.reset_index(inplace=True)
industries_scraped = industries_scraped[["company_name", "industry"]]
industries_scraped.drop_duplicates(inplace=True)
industries_scraped.value_counts()
# Out:
# company_name                    industry
#  Hitachi Vantara                ['Database management company in Singapore']                     1
# People Profilers Pte. Ltd.      ['Employment agency in Singapore']                               1
# Pearl Care Singapore Pte. Ltd.  [None]                                                           1
# Pegasystems Pte Ltd             ['Software company in Singapore']                                1
# Pelago                          ['Leisure', ' Travel & Tourism']                                 1
#                                                                                                 ..
# GREAT EASTERN                   ['Insurance', ' Financial Services', ' Banking', 'Insurance']    1
# GOOD FOR FOOD PTE. LTD.         ['Event planner in Singapore']                                   1
# GO-JEK                          ['Fund management company in Singapore']                         1
# GIC                             [None]                                                           1
# zendesk                         ['ITES/BPO']                                                     1
# Length: 2235, dtype: int64

# %%
def get_industry(text):
    """
    
    Args:
        text (str): string of industry based on scraping

    Returns:
        list: tokenized text
    """
    if text == 'NaN':
        return np.nan
    
    text = text.replace('[', '')
    text = text.replace(']', '')
    text = text.replace("'", '')
    mid_working = text.strip().split(',')
    to_be_returned = mid_working[0]
    return to_be_returned

def clean_str(text):
    if text == 'NaN':
        return np.nan
    
    text = text.replace('[', '')
    text = text.replace(']', '')
    text = text.replace("'", '')
    
    return text

def remove_locations(text): 
    text = text.replace('in Singapore', '')
    text = text.replace("in London", "")
    text = text.replace("in Pune", "")
    text = text.replace("in South Jakarta", "")
    text = text.replace("in Hong Kong", "")
#     text = text.replace("Bank", "Banking/Accounting/Financial Services")
#     text = text[0:-1]
    
    return text

industries_scraped['cleaned_industry'] = industries_scraped['industry'].apply(get_industry)
industries_scraped['cleaned_industry'] = industries_scraped['cleaned_industry'].apply(remove_locations)
industries_scraped['cleaned_industry'] = industries_scraped['cleaned_industry'].apply(clean_str)
industries_scraped['cleaned_industry'].value_counts()
# Out:
# None                                        507
# Software company                            225
# Corporate office                            145
# Employment agency                            83
# Information Technology & Services            70
#                                            ...
# Industrial consultant                         1
# Consumer Electronics/Durables/Appliances      1
# Advertising/Entertainment/Media               1
# Airlines/Aviation/Aerospace                   1
# Management consulting services company        1
# Name: cleaned_industry, Length: 290, dtype: int64

# %%
for i, row in industries_scraped.iterrows():
    company = row['company_name']
    df['industry'].loc[df['company_name'] == company] = str(row['cleaned_industry'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21456\2589049132.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['industry'].loc[df['company_name'] == company] = str(row['cleaned_industry'])

# %%
df.head()
# Out:
#                                         job_title  \
# 0                         Senior Python Developer
# 1  Senior Partner Solutions Architect (Microsoft)
# 7                     Cloud Engineer (Automation)
# 8                     Cloud Engineer (Automation)
# 9        Senior Software and Automation Architect
#
#                                    company_name   job_type  \
# 0                                          Citi  permanent
# 1                                        Amazon  permanent
# 7                      Recruit Expert Pte. Ltd.  permanent
# 8                      Recruit Expert Pte. Ltd.  permanent
# 9  Cisco International Limited Singapore Branch  permanent
#
#                                           tech_stack  \
# 0                                                NaN
# 1                                                NaN
# 7  ['Puppet', 'Cloud Applications', 'Cloud Securi...
# 8  ['Puppet', 'Cloud Applications', 'Cloud Securi...
# 9  ['Kubernetes', 'Cloud Computing', 'JIRA', 'Pyt...
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1  Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 7  In-charge of the design, deployment, installat...
# 8  In-charge of the design, deployment, installat...
# 9  What You'll Do\r\nCisco Customer Experience (C...
#
#                                 industry date_posted  \
# 0  Banking/Accounting/Financial Services  2022-02-18
# 1                    Internet/E-commerce  2022-02-18
# 7                     Employment agency   2022-02-19
# 8                     Employment agency   2022-03-14
# 9                     Employment agency   2022-02-19
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 1  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 7  https://www.monster.com.sg/seeker/job-details?...  monster       48000.0
# 8  https://www.monster.com.sg/seeker/job-details?...  monster       48000.0
# 9  https://www.monster.com.sg/seeker/job-details?...  monster      108000.0
#
#    ...  lower_year  upper_year  \
# 0  ...         NaN         NaN
# 1  ...         NaN         NaN
# 7  ...         2.0         5.0
# 8  ...         2.0         5.0
# 9  ...        10.0        15.0
#
#                                       all_tech_stack  \
# 0                                              set()
# 1                                              set()
# 7  {' Cloud Computing', ' Cloud-based', ' Cloud S...
# 8  {' Cloud Computing', ' Cloud-based', ' Cloud S...
# 9  {'Cisco', 'CircleCI', 'CI', 'Orchestration', '...
#
#                                     cleaned_job_desc              cluster  \
# 0  job description      job purpose   we are look...   Software Developer
# 1  job description    job summary  description  d...  Solutions Architect
# 7  in charge of the design  deployment  installat...       Cloud Engineer
# 8  in charge of the design  deployment  installat...       Cloud Engineer
# 9  what you ll do  cisco customer experience  cx ...  Solutions Architect
#
#           education_level                                    education_field  \
# 0                      {}                                                 {}
# 1              {Master's}                                                 {}
# 7  {Master's, Bachelor's}  {Computer Science, Information Technology, Rel...
# 8  {Master's, Bachelor's}  {Computer Science, Information Technology, Rel...
# 9                      {}                                                 {}
#
#   aws  google_cloud  azure
# 0   1             1      0
# 1   1             1      1
# 7   0             0      0
# 8   0             0      0
# 9   1             0      0
#
# [5 rows x 21 columns]

# %%
df.to_json("combined_data.json")

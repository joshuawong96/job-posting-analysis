# %%
import pandas as pd
import regex as re
import spacy

# %% [markdown]
# ### Reading each dataset

# %%
monster_data = pd.read_csv("../data/cleaned/individual_platforms/All_MonsterSg.csv", index_col=0)
monster_data.drop(["roles", "function"], axis=1, inplace=True)
monster_data.reset_index(inplace=True)
monster_data["source"] = 'monster'

monster_data.head(1)
# Out:
#                  job_title company salary   job_type years_experience  \
# 0  Senior Python Developer    Citi    NaN  permanent              NaN
#
#   tech_stack                                    job_description  \
# 0        NaN  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
#
#                                                  url   source
# 0  https://www.monster.com.sg/seeker/job-details?...  monster

# %%
linkedin_data = pd.read_csv("../data/cleaned/individual_platforms/LinkedIn.csv", index_col=0)
linkedin_data.drop(["applicantsCount", "remoteAllowed", "job_functions", "companyUrl"], axis=1, inplace=True)
linkedin_data.reset_index(inplace=True)
linkedin_data["source"] = 'linkedin'

linkedin_data.head(1)
# Out:
#                    job_title date_posted  \
# 0  Cloud Consumption Analyst  2021-10-07
#
#                                             job_desc       company_name  \
# 0  Job Description\r\n\r\nThe Cloud Consumption A...  Intel Corporation
#
#          industry   job_type                                             url  \
# 0  Semiconductors  permanent  https://www.linkedin.com/jobs/view/2773797384/
#
#      source
# 0  linkedin

# %%
nodeflair_data = pd.read_csv("../data/cleaned/individual_platforms/cleaned_nodeflair_jobpostings.csv", index_col=0)
nodeflair_data["source"] = 'nodeflair'

nodeflair_data.head(1)
# Out:
#                                      url                       job_title  \
# 0  https://www.nodeflair.com//jobs/53907  ReactJS Developer (Full Stack)
#
#         company_name              salary   job_type years_of_experience  \
# 0  Apar Technologies  ['6,419', '8,819']  Permanent              [2, 3]
#
#                                           tech_stack  \
# 0  ['Docker', 'CloudFoundry', 'Spring', 'SonarQub...
#
#                                             job_desc date_posted     source
# 0  We are looking for a candidate to fill in the ...  2022-03-10  nodeflair

# %%
print("Monster columns:", monster_data.columns)
print("LinkedIn columns:", linkedin_data.columns)
print("NodeFlair columns:", nodeflair_data.columns)
# Out:
# Monster columns: Index(['job_title', 'company', 'salary', 'job_type', 'years_experience',
#        'tech_stack', 'job_description', 'industry', 'date_posted', 'url',
#        'source'],
#       dtype='object')
# LinkedIn columns: Index(['job_title', 'date_posted', 'job_desc', 'company_name', 'industry',
#        'job_type', 'url', 'source'],
#       dtype='object')
# NodeFlair columns: Index(['url', 'job_title', 'company_name', 'salary', 'job_type',
#        'years_of_experience', 'tech_stack', 'job_desc', 'date_posted',
#        'source'],
#       dtype='object')

# %% [markdown]
# ### Standardising column names

# %%
monster_data.rename(columns={'company':'company_name', 'years_experience':'years_of_experience','job_description':'job_desc'}, inplace=True)

monster_data.head(1)
# Out:
#                  job_title company_name salary   job_type years_of_experience  \
# 0  Senior Python Developer         Citi    NaN  permanent                 NaN
#
#   tech_stack                                           job_desc  \
# 0        NaN  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
#
#                                                  url   source
# 0  https://www.monster.com.sg/seeker/job-details?...  monster

# %% [markdown]
# ### Combining all 3 datasets

# %%
combined_data = pd.concat([monster_data, linkedin_data, nodeflair_data])

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11448 entries, 0 to 2900
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_title            11448 non-null  object
#  1   company_name         11448 non-null  object
#  2   salary               5711 non-null   object
#  3   job_type             11441 non-null  object
#  4   years_of_experience  8969 non-null   object
#  5   tech_stack           7976 non-null   object
#  6   job_desc             11437 non-null  object
#  7   industry             9131 non-null   object
#  8   date_posted          10908 non-null  object
#  9   url                  11448 non-null  object
#  10  source               11448 non-null  object
# dtypes: object(11)
# memory usage: 1.0+ MB

# %%
combined_data.head(1)
# Out:
#                  job_title company_name salary   job_type years_of_experience  \
# 0  Senior Python Developer         Citi    NaN  permanent                 NaN
#
#   tech_stack                                           job_desc  \
# 0        NaN  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
#
#                                                  url   source
# 0  https://www.monster.com.sg/seeker/job-details?...  monster

# %% [markdown]
# ### Text Cleaning on Job Description

# %%
def clean_job_description(text):

    text = re.sub(r'\w*\d\w*','', str(text))
    text = text.replace("\r", " ").replace("\n", " ")
    text = re.sub(r'[^\w\s]', ' ', text)
    text = text.lower()

    return text

# %%
combined_data["cleaned_job_desc"] = combined_data["job_desc"].apply(clean_job_description)

# %% [markdown]
# ## Information Extraction

# %% [markdown]
# ### Extracting Salary Limits and Years of Experience Limits to individual columns

# %%
def get_lower_salary(text):
    if text == "NaN":
        return "NaN"

    elif type(text) != float:
        text = text[1:-1].split(", ")

        lower_salary = text[0].replace(",", "")
        return lower_salary[1:-1]

    else:
        return "NaN"

def get_upper_salary(text):
    if text == "NaN":
        return "NaN"

    elif type(text) != float:
        text = text[1:-1].split(", ")

        lower_salary = text[1].replace(",", "")
        return lower_salary[1:-1]

    else:
        return "NaN"

# %%
def get_lower_year(text):
    if text == "NaN":
        return "NaN"

    elif type(text) != float:
        if len(text.split(",")) == 1:
            return "NaN"
        else:
            text = text[1:-1].split(", ")

            lower_year = text[0].replace(",", "")
            return lower_year[1:-1]

    else:
        return "NaN"

def get_upper_year(text):
    if text == "NaN":
        return "NaN"

    elif type(text) != float:
        if len(text.split(",")) == 1:
            return text[1:-1]
        else:
            text = text[1:-1].split(", ")
            # print(text)
            # print(text[1])

            upper_year = text[1].replace(",", "")
            return upper_year[1:-1]

    else:
        return "NaN"

# %%
combined_data["lower_salary"] = combined_data["salary"].apply(get_lower_salary)
combined_data["upper_salary"] = combined_data["salary"].apply(get_upper_salary)
combined_data["lower_year"] = combined_data["years_of_experience"].apply(get_lower_year)
combined_data["upper_year"] = combined_data["years_of_experience"].apply(get_upper_year)

combined_data.drop(columns=["salary", "years_of_experience"], inplace=True)

combined_data.head()
# Out:
#                                         job_title  \
# 0                         Senior Python Developer
# 1  Senior Partner Solutions Architect (Microsoft)
# 2                                   IT Technician
# 3                               Customer Engineer
# 4                               Customer Engineer
#
#                                   company_name   job_type  \
# 0                                         Citi  permanent
# 1                                       Amazon  permanent
# 2                         Ascend Com Pte. Ltd.  permanent
# 3  Applied Materials South East Asia Pte. Ltd.  permanent
# 4  Applied Materials South East Asia Pte. Ltd.  permanent
#
#                                           tech_stack  \
# 0                                                NaN
# 1                                                NaN
# 2  ['Switches', 'Mac', 'Windows 10', 'Cloud Compu...
# 3  ['Scalability', 'Cloud Computing', 'Google Clo...
# 4  ['Scalability', 'Cloud Computing', 'Google Clo...
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1  Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 2  Responsibilities:\r\nProvide helpdesk support ...
# 3  Key Responsibilities\r\nPerforms all standard ...
# 4  Has developed specialized skills or is multi-s...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
# 1                    ['Internet/E-commerce']  2022-02-18
# 2                                  ['Other']  2022-02-19
# 3                                  ['Other']  2022-02-19
# 4                                  ['Other']  2022-02-19
#
#                                                  url   source lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster          NaN
# 1  https://www.monster.com.sg/seeker/job-details?...  monster          NaN
# 2  https://www.monster.com.sg/seeker/job-details?...  monster        24000
# 3  https://www.monster.com.sg/seeker/job-details?...  monster        42000
# 4  https://www.monster.com.sg/seeker/job-details?...  monster        46800
#
#   upper_salary lower_year upper_year
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2        36000          2          5
# 3        84000          2          5
# 4        93600          2          5

# %% [markdown]
# ### Consolidating Tech Stack for each Job Listing

# %%
skills_ner_model = spacy.load('../analysis/custom_ner_model')
ner=skills_ner_model.get_pipe('ner')

move_names = list(ner.move_names)
assert skills_ner_model.get_pipe("ner").move_names == move_names

# %%
def get_skills(text):
    skills_entities = []

    text = str(text).replace("\r", "").replace("\n", "")

    try:
        for sentence in text.split("."):
            doc = skills_ner_model(sentence)
            for ent in doc.ents:
                skills_entities.append(ent.text)
    except Exception as e:
        return ""

    return set(skills_entities)

# %%
combined_data["extracted_tech_stack"] = combined_data["job_desc"].apply(get_skills)

combined_data.head()
# Out:
#                                         job_title  \
# 0                         Senior Python Developer
# 1  Senior Partner Solutions Architect (Microsoft)
# 2                                   IT Technician
# 3                               Customer Engineer
# 4                               Customer Engineer
#
#                                   company_name   job_type  \
# 0                                         Citi  permanent
# 1                                       Amazon  permanent
# 2                         Ascend Com Pte. Ltd.  permanent
# 3  Applied Materials South East Asia Pte. Ltd.  permanent
# 4  Applied Materials South East Asia Pte. Ltd.  permanent
#
#                                           tech_stack  \
# 0                                                NaN
# 1                                                NaN
# 2  ['Switches', 'Mac', 'Windows 10', 'Cloud Compu...
# 3  ['Scalability', 'Cloud Computing', 'Google Clo...
# 4  ['Scalability', 'Cloud Computing', 'Google Clo...
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1  Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 2  Responsibilities:\r\nProvide helpdesk support ...
# 3  Key Responsibilities\r\nPerforms all standard ...
# 4  Has developed specialized skills or is multi-s...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
# 1                    ['Internet/E-commerce']  2022-02-18
# 2                                  ['Other']  2022-02-19
# 3                                  ['Other']  2022-02-19
# 4                                  ['Other']  2022-02-19
#
#                                                  url   source lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster          NaN
# 1  https://www.monster.com.sg/seeker/job-details?...  monster          NaN
# 2  https://www.monster.com.sg/seeker/job-details?...  monster        24000
# 3  https://www.monster.com.sg/seeker/job-details?...  monster        42000
# 4  https://www.monster.com.sg/seeker/job-details?...  monster        46800
#
#   upper_salary lower_year upper_year  \
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2        36000          2          5
# 3        84000          2          5
# 4        93600          2          5
#
#                                 extracted_tech_stack
# 0  {Mockito, Cucumber, Citigroup Inc, Oracle, BI,...
# 1  {Identity, Active Directory, API's, Microsoft ...
# 2  {MaintenanceComputer Hardware, Office, 1st &, ...
# 3  {Tier, SolvingRecognizes, IP, guidanceInterper...
# 4                           {Tier II, IP, Revs, BKM}

# %%
# combined_data.reset_index(inplace=True)
# combined_data.to_json('../data cleaning/extracted_tech_stack.json', orient='columns')

combined_data = pd.read_json("extracted_tech_stack.json")
combined_data.drop(columns=["index"], inplace=True)
combined_data.head(5)
# Out:
#                                         job_title  \
# 0                         Senior Python Developer
# 1  Senior Partner Solutions Architect (Microsoft)
# 2                                   IT Technician
# 3                               Customer Engineer
# 4                               Customer Engineer
#
#                                   company_name   job_type  \
# 0                                         Citi  permanent
# 1                                       Amazon  permanent
# 2                         Ascend Com Pte. Ltd.  permanent
# 3  Applied Materials South East Asia Pte. Ltd.  permanent
# 4  Applied Materials South East Asia Pte. Ltd.  permanent
#
#                                           tech_stack  \
# 0                                               None
# 1                                               None
# 2  ['Switches', 'Mac', 'Windows 10', 'Cloud Compu...
# 3  ['Scalability', 'Cloud Computing', 'Google Clo...
# 4  ['Scalability', 'Cloud Computing', 'Google Clo...
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1  Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 2  Responsibilities:\r\nProvide helpdesk support ...
# 3  Key Responsibilities\r\nPerforms all standard ...
# 4  Has developed specialized skills or is multi-s...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
# 1                    ['Internet/E-commerce']  2022-02-18
# 2                                  ['Other']  2022-02-19
# 3                                  ['Other']  2022-02-19
# 4                                  ['Other']  2022-02-19
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 1  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 2  https://www.monster.com.sg/seeker/job-details?...  monster       24000.0
# 3  https://www.monster.com.sg/seeker/job-details?...  monster       42000.0
# 4  https://www.monster.com.sg/seeker/job-details?...  monster       46800.0
#
#    upper_salary lower_year upper_year  \
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2       36000.0          2          5
# 3       84000.0          2          5
# 4       93600.0          2          5
#
#                                 extracted_tech_stack
# 0  [Mockito, Cucumber, Citigroup Inc, Oracle, BI,...
# 1  [Identity, Active Directory, API's, Microsoft ...
# 2  [MaintenanceComputer Hardware, Office, 1st &, ...
# 3  [Tier, SolvingRecognizes, IP, guidanceInterper...
# 4                           [Tier II, IP, Revs, BKM]

# %%
def consolidate_tech_stack(row):
    all_tech_stack = []
    text = str(row["tech_stack"])

    if text != 'NaN':
        text = text[1:-1]
        text = text.replace("'", "")
        text = text.split(", ")

        for tech_stack in text:
            all_tech_stack.append(tech_stack)
    
        all_tech_stack += list(row["extracted_tech_stack"])

    return set(all_tech_stack)

# %%
combined_data["all_tech_stack"] = combined_data.apply(consolidate_tech_stack, axis=1)

combined_data.head()
# Out:
#                                         job_title  \
# 0                         Senior Python Developer
# 1  Senior Partner Solutions Architect (Microsoft)
# 2                                   IT Technician
# 3                               Customer Engineer
# 4                               Customer Engineer
#
#                                   company_name   job_type  \
# 0                                         Citi  permanent
# 1                                       Amazon  permanent
# 2                         Ascend Com Pte. Ltd.  permanent
# 3  Applied Materials South East Asia Pte. Ltd.  permanent
# 4  Applied Materials South East Asia Pte. Ltd.  permanent
#
#                                           tech_stack  \
# 0                                               None
# 1                                               None
# 2  ['Switches', 'Mac', 'Windows 10', 'Cloud Compu...
# 3  ['Scalability', 'Cloud Computing', 'Google Clo...
# 4  ['Scalability', 'Cloud Computing', 'Google Clo...
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1  Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 2  Responsibilities:\r\nProvide helpdesk support ...
# 3  Key Responsibilities\r\nPerforms all standard ...
# 4  Has developed specialized skills or is multi-s...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
# 1                    ['Internet/E-commerce']  2022-02-18
# 2                                  ['Other']  2022-02-19
# 3                                  ['Other']  2022-02-19
# 4                                  ['Other']  2022-02-19
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 1  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 2  https://www.monster.com.sg/seeker/job-details?...  monster       24000.0
# 3  https://www.monster.com.sg/seeker/job-details?...  monster       42000.0
# 4  https://www.monster.com.sg/seeker/job-details?...  monster       46800.0
#
#    upper_salary lower_year upper_year  \
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2       36000.0          2          5
# 3       84000.0          2          5
# 4       93600.0          2          5
#
#                                 extracted_tech_stack  \
# 0  [Mockito, Cucumber, Citigroup Inc, Oracle, BI,...
# 1  [Identity, Active Directory, API's, Microsoft ...
# 2  [MaintenanceComputer Hardware, Office, 1st &, ...
# 3  [Tier, SolvingRecognizes, IP, guidanceInterper...
# 4                           [Tier II, IP, Revs, BKM]
#
#                                       all_tech_stack
# 0  {RabbitMQ, Tableau Dashboards, Bitbucket, SOAP...
# 1  {Queue, Containers, Azure, RFPs, Microsoft ELA...
# 2  {Computer Hardware, Switches, LAN, Firewall, N...
# 3  {Knowledge Management, Problem Solving, BKM, R...
# 4  {Knowledge Management, Problem Solving, BKM, R...

# %%
combined_data.iloc[0]["all_tech_stack"]
# Out:
# {'APAC Cross',
#  'AWS',
#  'Angular',
#  'Ant',
#  'BI',
#  'Big Data',
#  'Bitbucket',
#  'CMAD',
#  'CSS',
#  'Citi',
#  'Citigroup Inc',
#  'Cloud Computing',
#  'Cloud Foundry)Good',
#  'Cloud Platforms',
#  'Container',
#  'Core &',
#  'Cucumber',
#  'Dev',
#  'Docker',
#  'EHCache',
#  'GIT',
#  'Gemfire',
#  'Google Cloud',
#  'HTML 5',
#  'Hazlecast',
#  'Integration',
#  'JIRA',
#  'JMS',
#  'JSON',
#  'JUnit',
#  'Jasmin',
#  'Java',
#  'JavaScript',
#  'Jenkins',
#  'Kafka',
#  'Karma',
#  'Kubernetes',
#  'Maven',
#  'MicroServices',
#  'Mockito',
#  'Mule',
#  'Oracle',
#  'Orchestration',
#  'PostgreSQL',
#  'Python',
#  'REST',
#  'RabbitMQ',
#  'SOAP',
#  'SQL',
#  'Selenium',
#  'Skills',
#  'Sonar',
#  'Spring Boot',
#  'Spring Cloud',
#  'Spring MVC',
#  'Tableau',
#  'Tableau Dashboards',
#  'Testing',
#  'Tools',
#  'UI',
#  'UX',
#  'Web Technologies',
#  'big data',
#  'color',
#  'national origin',
#  'on',
#  'religion',
#  'resource-',
#  'sex'}

# %% [markdown]
# ### Extracting Education Level and Field of Study from Job Postings

# %%
level_dict = {
    "PhD": ["phd", "doctor", "doctorate"],
    "Master's": ["masters degree", "master", "master's degree", " ms "],
    "Bachelor's": ["bachelor's degree", "bachelor degree", "bachelor's", "bachelor", "degree", "bsc", " bs ", "college", "university"],
    "Diploma": ["diploma"]
}

field_dict = {
    "Relevant Field": ["related", "relevant", "equivalent", "related field", "related discipline", "technical field", "related area"],
    "Computer Science": ["computer science", " cs ", "comp sci", "com sci", "computing"],
    "Mathematics": ["mathematics", "math"],
    "Information Technology": ["information technology", " it ", "technology", "information systems", "digital technologies"],
    "Computer/Software Engineering": ["computer engineering", "software engineering"],
    "Electrical and Electronics Engineering": ["electrical and electronics engineering", "bsee", "electrical engineering", "electronics engineering"],
    "Physics": ["physics"],
    "Business": ["business", "MBA"]
}

# %%
# Initialise empty rows
combined_data['education_level'] = combined_data.apply(lambda x: set(), axis=1)
combined_data['education_field'] = combined_data.apply(lambda x: set(), axis=1)

# %%
# Iterate through level dictionary and level variations
for level, level_list in level_dict.items():
    for level_variation in level_list:
        # Iterate through dataframe
        for i, row in combined_data.iterrows():
            # If description is a string, and contains level_variation, append level
            if type(row['cleaned_job_desc']) == str and re.search(level_variation, row['cleaned_job_desc']) is not None:
                combined_data.at[i, "education_level"].add(level)
                # Iterate through matches of level_variations
                for match in re.finditer(level_variation, row['cleaned_job_desc']):
                    # Iterate through field dictionary and field variations
                    for field, field_list in field_dict.items():
                        for field_variation in field_list:
                            # If field_variation within 100 characters of match, append field
                            if field_variation in row['cleaned_job_desc'][match.start():match.end()+100]:
                                combined_data.at[i, "education_field"].add(field)
combined_data
# Out:
#                                             job_title  \
# 0                             Senior Python Developer
# 1      Senior Partner Solutions Architect (Microsoft)
# 2                                       IT Technician
# 3                                   Customer Engineer
# 4                                   Customer Engineer
# ...                                               ...
# 11443                                 DevOps Engineer
# 11444                                 DevOps Engineer
# 11445                                 DevOps Engineer
# 11446                               Software Engineer
# 11447          Sr. Site Reliability Engineer - Hadoop
#
#                                       company_name   job_type  \
# 0                                             Citi  permanent
# 1                                           Amazon  permanent
# 2                             Ascend Com Pte. Ltd.  permanent
# 3      Applied Materials South East Asia Pte. Ltd.  permanent
# 4      Applied Materials South East Asia Pte. Ltd.  permanent
# ...                                            ...        ...
# 11443                                         2C2P  Permanent
# 11444                                      FINXFLO  Permanent
# 11445                                     Quilt.AI  Permanent
# 11446                     Zoku Integrated Commerce  Permanent
# 11447                            Xiaomi Technology  Permanent
#
#                                               tech_stack  \
# 0                                                   None
# 1                                                   None
# 2      ['Switches', 'Mac', 'Windows 10', 'Cloud Compu...
# 3      ['Scalability', 'Cloud Computing', 'Google Clo...
# 4      ['Scalability', 'Cloud Computing', 'Google Clo...
# ...                                                  ...
# 11443  ['GitLab', 'HTTP', 'UDP', 'TCP', 'ShellScript'...
# 11444  ['Strategy', 'ShellScript', 'CI', 'Shell', 'UN...
# 11445  ['Next.js', 'Docker', 'Cloudflare', 'DockerSwa...
# 11446  ['API', 'Magento', 'CI', 'DOM', 'Node.js', 'No...
# 11447  ['MapReduce', 'API', 'Container', 'JMX', 'Anal...
#
#                                                 job_desc  \
# 0      Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1      Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 2      Responsibilities:\r\nProvide helpdesk support ...
# 3      Key Responsibilities\r\nPerforms all standard ...
# 4      Has developed specialized skills or is multi-s...
# ...                                                  ...
# 11443  2C2P is looking for a .NET DevOps Engineer to ...
# 11444  Alpha Stone Capital is looking for an amazing ...
# 11445  As part of a growing team consisting of ML exp...
# 11446  We are hiring software engineers with expertis...
# 11447  Job Requirement： Deploy, operate, maintain, se...
#
#                                         industry date_posted  \
# 0      ['Banking/Accounting/Financial Services']  2022-02-18
# 1                        ['Internet/E-commerce']  2022-02-18
# 2                                      ['Other']  2022-02-19
# 3                                      ['Other']  2022-02-19
# 4                                      ['Other']  2022-02-19
# ...                                          ...         ...
# 11443                                       None  2022-01-11
# 11444                                       None  2022-01-11
# 11445                                       None  2022-01-11
# 11446                                       None  2022-01-11
# 11447                                       None  2022-01-11
#
#                                                      url     source  \
# 0      https://www.monster.com.sg/seeker/job-details?...    monster
# 1      https://www.monster.com.sg/seeker/job-details?...    monster
# 2      https://www.monster.com.sg/seeker/job-details?...    monster
# 3      https://www.monster.com.sg/seeker/job-details?...    monster
# 4      https://www.monster.com.sg/seeker/job-details?...    monster
# ...                                                  ...        ...
# 11443              https://www.nodeflair.com//jobs/46156  nodeflair
# 11444              https://www.nodeflair.com//jobs/46153  nodeflair
# 11445              https://www.nodeflair.com//jobs/46151  nodeflair
# 11446              https://www.nodeflair.com//jobs/46149  nodeflair
# 11447              https://www.nodeflair.com//jobs/46147  nodeflair
#
#        lower_salary  upper_salary lower_year upper_year  \
# 0               NaN           NaN        NaN        NaN
# 1               NaN           NaN        NaN        NaN
# 2           24000.0       36000.0          2          5
# 3           42000.0       84000.0          2          5
# 4           46800.0       93600.0          2          5
# ...             ...           ...        ...        ...
# 11443        7000.0       10000.0        NaN          3
# 11444           NaN           NaN        NaN        NaN
# 11445           NaN           NaN        NaN          3
# 11446           NaN           NaN        NaN          3
# 11447           NaN           NaN        NaN        NaN
#
#                                     extracted_tech_stack  \
# 0      [Mockito, Cucumber, Citigroup Inc, Oracle, BI,...
# 1      [Identity, Active Directory, API's, Microsoft ...
# 2      [MaintenanceComputer Hardware, Office, 1st &, ...
# 3      [Tier, SolvingRecognizes, IP, guidanceInterper...
# 4                               [Tier II, IP, Revs, BKM]
# ...                                                  ...
# 11443  [Terraform, Python, TCP, Amazon Web, IP, IaC, ...
# 11444  [SysOps, Infrastructure &, DevOps Engineer, Py...
# 11445  [Terraform, DevOps Engineer, Python, Cloudflar...
# 11446  [Experience Codes, Magento, NodeJS, Bachelor’s...
# 11447  [HDFS, Java, Kibana, Python, MapReduce, playbo...
#
#                                           all_tech_stack  \
# 0      {RabbitMQ, Tableau Dashboards, Bitbucket, SOAP...
# 1      {Queue, Containers, Azure, RFPs, Microsoft ELA...
# 2      {Computer Hardware, Switches, LAN, Firewall, N...
# 3      {Knowledge Management, Problem Solving, BKM, R...
# 4      {Knowledge Management, Problem Solving, BKM, R...
# ...                                                  ...
# 11443  {IaC, TCP, .NET, Ansible Strong, Node.js, UDP,...
# 11444  {IaC, SysOps, Terraform Team, BS, Terraform, A...
# 11445  {IaC, React, Container, Docker, Ansible, Prefe...
# 11446  {DOM, Node.js, React, TypeScript, API, ERP, ba...
# 11447  {Container, ZooKeeper, Go, API, HBase, configu...
#
#               education_level  \
# 0                          {}
# 1                  {Master's}
# 2                   {Diploma}
# 3                          {}
# 4                {Bachelor's}
# ...                       ...
# 11443                      {}
# 11444  {Master's, Bachelor's}
# 11445            {Bachelor's}
# 11446            {Bachelor's}
# 11447            {Bachelor's}
#
#                                          education_field  \
# 0                                                     {}
# 1                                                     {}
# 2               {Relevant Field, Information Technology}
# 3                                                     {}
# 4                                                     {}
# ...                                                  ...
# 11443                                                 {}
# 11444                 {Relevant Field, Computer Science}
# 11445  {Relevant Field, Computer Science, Computer/So...
# 11446                 {Relevant Field, Computer Science}
# 11447                 {Relevant Field, Computer Science}
#
#                                         cleaned_job_desc
# 0      job description      job purpose   we are look...
# 1      job description    job summary  description  d...
# 2      responsibilities   provide helpdesk support fo...
# 3      key responsibilities  performs all standard se...
# 4      has developed specialized skills or is multi s...
# ...                                                  ...
# 11443   is looking for a  net devops engineer to join...
# 11444  alpha stone capital is looking for an amazing ...
# 11445  as part of a growing team consisting of ml exp...
# 11446  we are hiring software engineers with expertis...
# 11447  job requirement  deploy  operate  maintain  se...
#
# [11448 rows x 18 columns]

# %% [markdown]
# ### Extracting Cloud Service Provider

# %%
combined_data['aws'] = 0
combined_data['google_cloud'] = 0
combined_data['azure'] = 0

combined_data.head(1)
# Out:
#                  job_title company_name   job_type tech_stack  \
# 0  Senior Python Developer         Citi  permanent       None
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
#
#                                     industry date_posted  \
# 0  ['Banking/Accounting/Financial Services']  2022-02-18
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
#
#    ...  lower_year upper_year  \
# 0  ...         NaN        NaN
#
#                                 extracted_tech_stack  \
# 0  [Mockito, Cucumber, Citigroup Inc, Oracle, BI,...
#
#                                       all_tech_stack education_level  \
# 0  {RabbitMQ, Tableau Dashboards, Bitbucket, SOAP...              {}
#
#   education_field                                   cleaned_job_desc aws  \
# 0              {}  job description      job purpose   we are look...   0
#
#    google_cloud  azure
# 0             0      0
#
# [1 rows x 21 columns]

# %%
for i, row in combined_data.iterrows():
    job_desc = str(row['cleaned_job_desc'])
    if "aws" in job_desc or "amazon web services" in job_desc:
        combined_data.at[i,'aws'] = 1
    if "google cloud platform" in job_desc or "gcp" in job_desc:
        combined_data.at[i,'google_cloud'] = 1
    if "azure" in job_desc:
        combined_data.at[i,'azure'] = 1

# %%
combined_data["aws"].value_counts()
# Out:
# 0    6207
# 1    5241
# Name: aws, dtype: int64

# %%
combined_data["google_cloud"].value_counts()
# Out:
# 0    10084
# 1     1364
# Name: google_cloud, dtype: int64

# %%
combined_data["azure"].value_counts()
# Out:
# 0    8664
# 1    2784
# Name: azure, dtype: int64

# %% [markdown]
# ### Assign Industry for each Job Posting

# %%
industries_scraped = pd.read_csv("../data/cleaned/Posts_Industry.csv", index_col=0)
industries_scraped.reset_index(inplace=True)
industries_scraped = industries_scraped[["company_name", "industry"]]
industries_scraped.drop_duplicates(inplace=True)
industries_scraped.value_counts()
# Out:
# company_name                    industry
#  Hitachi Vantara                ['Database management company in Singapore']                     1
# People Profilers Pte. Ltd.      ['Employment agency in Singapore']                               1
# Pearl Care Singapore Pte. Ltd.  [None]                                                           1
# Pegasystems Pte Ltd             ['Software company in Singapore']                                1
# Pelago                          ['Leisure', ' Travel & Tourism']                                 1
#                                                                                                 ..
# GREAT EASTERN                   ['Insurance', ' Financial Services', ' Banking', 'Insurance']    1
# GOOD FOR FOOD PTE. LTD.         ['Event planner in Singapore']                                   1
# GO-JEK                          ['Fund management company in Singapore']                         1
# GIC                             [None]                                                           1
# zendesk                         ['ITES/BPO']                                                     1
# Length: 2235, dtype: int64

# %%
def get_industry(text):
    if text == 'NaN':
        return np.nan
    
    text = text.replace('[', '')
    text = text.replace(']', '')
    text = text.replace("'", '')
    mid_working = text.strip().split(',')
    to_be_returned = mid_working[0]

    return to_be_returned

def clean_str(text):
    if text == 'NaN':
        return np.nan
    to_be_returned = ""
    text = text.replace('[', '')
    text = text.replace(']', '')
    text = text.replace("'", '')

    text = text.rstrip()

    return text



def remove_locations(text): 
    text = text.replace('in Singapore', '')
    text = text.replace("in London", "")
    text = text.replace("in Pune", "")
    text = text.replace("in South Jakarta", "")
    text = text.replace("in Hong Kong", "")
    
    text = text.replace("company", "")
    text = text.replace("office", "")
    
    text = text.replace("IT/Computers - Software","IT")
    text = text.replace("Software","IT")
    
    
    
#     text = text.replace("Bank", "Banking/Accounting/Financial Services")
#     text = text[0:-1]
    
    return text

industries_scraped['cleaned_industry'] = industries_scraped['industry'].apply(get_industry)
industries_scraped['cleaned_industry'] = industries_scraped['cleaned_industry'].apply(remove_locations)
industries_scraped['cleaned_industry'] = industries_scraped['cleaned_industry'].apply(clean_str)
industries_scraped['cleaned_industry'].value_counts()
# Out:
# None                                 507
# IT                                   294
# Corporate                            145
# Employment agency                     83
# Information Technology & Services     70
#                                     ...
# Travel agency                          1
# Engineering services                   1
# Entertainment/Media/Publishing         1
# Marketing consultant                   1
# Management consulting services         1
# Name: cleaned_industry, Length: 277, dtype: int64

# %%
for i, row in industries_scraped.iterrows():
    company = row['company_name']
    combined_data['industry'].loc[combined_data['company_name'] == company] = str(row['cleaned_industry'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19696\131205118.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_data['industry'].loc[combined_data['company_name'] == company] = str(row['cleaned_industry'])

# %%
combined_data.head(5)
# Out:
#                                         job_title  \
# 0                         Senior Python Developer
# 1  Senior Partner Solutions Architect (Microsoft)
# 2                                   IT Technician
# 3                               Customer Engineer
# 4                               Customer Engineer
#
#                                   company_name   job_type  \
# 0                                         Citi  permanent
# 1                                       Amazon  permanent
# 2                         Ascend Com Pte. Ltd.  permanent
# 3  Applied Materials South East Asia Pte. Ltd.  permanent
# 4  Applied Materials South East Asia Pte. Ltd.  permanent
#
#                                           tech_stack  \
# 0                                               None
# 1                                               None
# 2  ['Switches', 'Mac', 'Windows 10', 'Cloud Compu...
# 3  ['Scalability', 'Cloud Computing', 'Google Clo...
# 4  ['Scalability', 'Cloud Computing', 'Google Clo...
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1  Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 2  Responsibilities:\r\nProvide helpdesk support ...
# 3  Key Responsibilities\r\nPerforms all standard ...
# 4  Has developed specialized skills or is multi-s...
#
#                                 industry date_posted  \
# 0  Banking/Accounting/Financial Services  2022-02-18
# 1                    Internet/E-commerce  2022-02-18
# 2                              Corporate  2022-02-19
# 3                Semi conductor supplier  2022-02-19
# 4                Semi conductor supplier  2022-02-19
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 1  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 2  https://www.monster.com.sg/seeker/job-details?...  monster       24000.0
# 3  https://www.monster.com.sg/seeker/job-details?...  monster       42000.0
# 4  https://www.monster.com.sg/seeker/job-details?...  monster       46800.0
#
#    ...  lower_year upper_year  \
# 0  ...         NaN        NaN
# 1  ...         NaN        NaN
# 2  ...           2          5
# 3  ...           2          5
# 4  ...           2          5
#
#                                 extracted_tech_stack  \
# 0  [Mockito, Cucumber, Citigroup Inc, Oracle, BI,...
# 1  [Identity, Active Directory, API's, Microsoft ...
# 2  [MaintenanceComputer Hardware, Office, 1st &, ...
# 3  [Tier, SolvingRecognizes, IP, guidanceInterper...
# 4                           [Tier II, IP, Revs, BKM]
#
#                                       all_tech_stack education_level  \
# 0  {RabbitMQ, Tableau Dashboards, Bitbucket, SOAP...              {}
# 1  {Queue, Containers, Azure, RFPs, Microsoft ELA...      {Master's}
# 2  {Computer Hardware, Switches, LAN, Firewall, N...       {Diploma}
# 3  {Knowledge Management, Problem Solving, BKM, R...              {}
# 4  {Knowledge Management, Problem Solving, BKM, R...    {Bachelor's}
#
#                             education_field  \
# 0                                        {}
# 1                                        {}
# 2  {Relevant Field, Information Technology}
# 3                                        {}
# 4                                        {}
#
#                                     cleaned_job_desc aws  google_cloud  azure
# 0  job description      job purpose   we are look...   1             1      0
# 1  job description    job summary  description  d...   1             1      1
# 2  responsibilities   provide helpdesk support fo...   0             0      0
# 3  key responsibilities  performs all standard se...   0             0      0
# 4  has developed specialized skills or is multi s...   0             0      0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Lowercase Job Type and Company Name

# %%
combined_data['job_type'] = combined_data['job_type'].str.lower()
combined_data['company_name'] = combined_data['company_name'].str.lower()

combined_data.head(5)
# Out:
#                                         job_title  \
# 0                         Senior Python Developer
# 1  Senior Partner Solutions Architect (Microsoft)
# 2                                   IT Technician
# 3                               Customer Engineer
# 4                               Customer Engineer
#
#                                   company_name   job_type  \
# 0                                         citi  permanent
# 1                                       amazon  permanent
# 2                         ascend com pte. ltd.  permanent
# 3  applied materials south east asia pte. ltd.  permanent
# 4  applied materials south east asia pte. ltd.  permanent
#
#                                           tech_stack  \
# 0                                               None
# 1                                               None
# 2  ['Switches', 'Mac', 'Windows 10', 'Cloud Compu...
# 3  ['Scalability', 'Cloud Computing', 'Google Clo...
# 4  ['Scalability', 'Cloud Computing', 'Google Clo...
#
#                                             job_desc  \
# 0  Job Description :\r\n\r\nJob Purpose:\r\nWe ar...
# 1  Job Description :\r\nJob summary\r\nDESCRIPTIO...
# 2  Responsibilities:\r\nProvide helpdesk support ...
# 3  Key Responsibilities\r\nPerforms all standard ...
# 4  Has developed specialized skills or is multi-s...
#
#                                 industry date_posted  \
# 0  Banking/Accounting/Financial Services  2022-02-18
# 1                    Internet/E-commerce  2022-02-18
# 2                              Corporate  2022-02-19
# 3                Semi conductor supplier  2022-02-19
# 4                Semi conductor supplier  2022-02-19
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 1  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 2  https://www.monster.com.sg/seeker/job-details?...  monster       24000.0
# 3  https://www.monster.com.sg/seeker/job-details?...  monster       42000.0
# 4  https://www.monster.com.sg/seeker/job-details?...  monster       46800.0
#
#    ...  lower_year upper_year  \
# 0  ...         NaN        NaN
# 1  ...         NaN        NaN
# 2  ...           2          5
# 3  ...           2          5
# 4  ...           2          5
#
#                                 extracted_tech_stack  \
# 0  [Mockito, Cucumber, Citigroup Inc, Oracle, BI,...
# 1  [Identity, Active Directory, API's, Microsoft ...
# 2  [MaintenanceComputer Hardware, Office, 1st &, ...
# 3  [Tier, SolvingRecognizes, IP, guidanceInterper...
# 4                           [Tier II, IP, Revs, BKM]
#
#                                       all_tech_stack education_level  \
# 0  {RabbitMQ, Tableau Dashboards, Bitbucket, SOAP...              {}
# 1  {Queue, Containers, Azure, RFPs, Microsoft ELA...      {Master's}
# 2  {Computer Hardware, Switches, LAN, Firewall, N...       {Diploma}
# 3  {Knowledge Management, Problem Solving, BKM, R...              {}
# 4  {Knowledge Management, Problem Solving, BKM, R...    {Bachelor's}
#
#                             education_field  \
# 0                                        {}
# 1                                        {}
# 2  {Relevant Field, Information Technology}
# 3                                        {}
# 4                                        {}
#
#                                     cleaned_job_desc aws  google_cloud  azure
# 0  job description      job purpose   we are look...   1             1      0
# 1  job description    job summary  description  d...   1             1      1
# 2  responsibilities   provide helpdesk support fo...   0             0      0
# 3  key responsibilities  performs all standard se...   0             0      0
# 4  has developed specialized skills or is multi s...   0             0      0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Add Clusters for each Job Posting

# %%
clustered_roles = pd.read_csv("../data/cleaned/unfiltered_df.csv", index_col=0)
clustered_roles = clustered_roles["Cluster"]
clustered_roles
# Out:
# 0         Software Developer
# 1        Solutions Architect
# 2                     Others
# 3                     Others
# 4                     Others
#                 ...
# 11443        Devops Engineer
# 11444        Devops Engineer
# 11445        Devops Engineer
# 11446      Software Engineer
# 11447                 Others
# Name: Cluster, Length: 11448, dtype: object

# %%
combined_data["cluster"] = clustered_roles

# %%
filtered_clusters = combined_data[combined_data["cluster"] != "Others"]
filtered_clusters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5405 entries, 0 to 11446
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   job_title         5405 non-null   object
#  1   company_name      5405 non-null   object
#  2   job_type          5402 non-null   object
#  3   industry          5405 non-null   object
#  4   date_posted       5046 non-null   object
#  5   url               5405 non-null   object
#  6   source            5405 non-null   object
#  7   lower_salary      2874 non-null   float64
#  8   upper_salary      2874 non-null   float64
#  9   lower_year        5405 non-null   object
#  10  upper_year        5405 non-null   object
#  11  all_tech_stack    5405 non-null   object
#  12  education_level   5405 non-null   object
#  13  education_field   5405 non-null   object
#  14  cleaned_job_desc  5405 non-null   object
#  15  aws               5405 non-null   int64
#  16  google_cloud      5405 non-null   int64
#  17  azure             5405 non-null   int64
#  18  cluster           5405 non-null   object
# dtypes: float64(2), int64(3), object(14)
# memory usage: 844.5+ KB

# %% [markdown]
# ## Remove redundant columns

# %%
combined_data.columns
# Out:
# Index(['job_title', 'company_name', 'job_type', 'tech_stack', 'job_desc',
#        'industry', 'date_posted', 'url', 'source', 'lower_salary',
#        'upper_salary', 'lower_year', 'upper_year', 'extracted_tech_stack',
#        'all_tech_stack', 'education_level', 'education_field',
#        'cleaned_job_desc', 'aws', 'google_cloud', 'azure', 'cluster'],
#       dtype='object')

# %%
combined_data.drop(columns=["tech_stack", "extracted_tech_stack", "job_desc"], inplace=True)
combined_data.head(5)
# Out:
#                                         job_title  \
# 0                         Senior Python Developer
# 1  Senior Partner Solutions Architect (Microsoft)
# 2                                   IT Technician
# 3                               Customer Engineer
# 4                               Customer Engineer
#
#                                   company_name   job_type  \
# 0                                         citi  permanent
# 1                                       amazon  permanent
# 2                         ascend com pte. ltd.  permanent
# 3  applied materials south east asia pte. ltd.  permanent
# 4  applied materials south east asia pte. ltd.  permanent
#
#                                 industry date_posted  \
# 0  Banking/Accounting/Financial Services  2022-02-18
# 1                    Internet/E-commerce  2022-02-18
# 2                              Corporate  2022-02-19
# 3                Semi conductor supplier  2022-02-19
# 4                Semi conductor supplier  2022-02-19
#
#                                                  url   source  lower_salary  \
# 0  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 1  https://www.monster.com.sg/seeker/job-details?...  monster           NaN
# 2  https://www.monster.com.sg/seeker/job-details?...  monster       24000.0
# 3  https://www.monster.com.sg/seeker/job-details?...  monster       42000.0
# 4  https://www.monster.com.sg/seeker/job-details?...  monster       46800.0
#
#    upper_salary lower_year upper_year  \
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2       36000.0          2          5
# 3       84000.0          2          5
# 4       93600.0          2          5
#
#                                       all_tech_stack education_level  \
# 0  {RabbitMQ, Tableau Dashboards, Bitbucket, SOAP...              {}
# 1  {Queue, Containers, Azure, RFPs, Microsoft ELA...      {Master's}
# 2  {Computer Hardware, Switches, LAN, Firewall, N...       {Diploma}
# 3  {Knowledge Management, Problem Solving, BKM, R...              {}
# 4  {Knowledge Management, Problem Solving, BKM, R...    {Bachelor's}
#
#                             education_field  \
# 0                                        {}
# 1                                        {}
# 2  {Relevant Field, Information Technology}
# 3                                        {}
# 4                                        {}
#
#                                     cleaned_job_desc  aws  google_cloud  \
# 0  job description      job purpose   we are look...    1             1
# 1  job description    job summary  description  d...    1             1
# 2  responsibilities   provide helpdesk support fo...    0             0
# 3  key responsibilities  performs all standard se...    0             0
# 4  has developed specialized skills or is multi s...    0             0
#
#    azure              cluster
# 0      0   Software Developer
# 1      1  Solutions Architect
# 2      0               Others
# 3      0               Others
# 4      0               Others

# %%
combined_data.to_json("../data/cleaned/combined_data.json", orient="columns")

# %%
filtered_clusters.to_json("../data/cleaned/filtered_data.json", orient="columns")

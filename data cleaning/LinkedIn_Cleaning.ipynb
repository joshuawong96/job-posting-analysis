# %%
import pandas as pd
import os 
import numpy as np
import re
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Change directory
directory = os.chdir("/Users/joshuawong/Documents/GitHub/job-posting-analysis/data/raw/Linkedin")
files = os.listdir(".")
files
# Out:
# ['cloud_posts_steph.csv',
#  'cloud_posts_joshua.csv',
#  'cloud_links.csv',
#  'cloud_posts_lingjia.csv',
#  'cloud_posts_gihan.csv',
#  'cloud_posts_darren.csv']

# %%
# get all relevant files in df
# Change filename

relevant_csv = [x for x in files if 'posts' in x]
relevant_csv
# Out:
# ['cloud_posts_steph.csv',
#  'cloud_posts_joshua.csv',
#  'cloud_posts_lingjia.csv',
#  'cloud_posts_gihan.csv',
#  'cloud_posts_darren.csv']

# %%
# Combine all csv
df = pd.concat(map(pd.read_csv, relevant_csv), ignore_index=True, axis=0)
df
# Out:
#                                               jobTitle           jobLocation  \
# 0    Cloud Security Architect (National Strategic P...  Singapore, Singapore
# 1    Senior Consultant - Cloud Solutions Architect ...  Singapore, Singapore
# 2    Software Engineer (Observability SaaS Platform...  Singapore, Singapore
# 3                               Data Engineer (EduHub)  Singapore, Singapore
# 4                              Hybrid Cloud Consultant             Singapore
# ..                                                 ...                   ...
# 802               Cloud Partner Success Manager (APAC)  Singapore, Singapore
# 803                     Java (Cloud Native) Developer   Singapore, Singapore
# 804                     Cloud Native Developer (Azure)  Singapore, Singapore
# 805    Salesforce Marketing Cloud Technical Specialist  Singapore, Singapore
# 806                             Cloud Native Developer  Singapore, Singapore
#
#      applicantsCount  viewsCount  \
# 0                1.0        23.0
# 1              126.0       988.0
# 2               17.0       170.0
# 3               16.0       126.0
# 4               19.0       113.0
# ..               ...         ...
# 802              7.0        51.0
# 803              4.0        32.0
# 804              3.0        17.0
# 805             29.0       222.0
# 806              2.0        14.0
#
#                                    jobPosterProfileUrl  \
# 0                                                  NaN
# 1                                                  NaN
# 2    https://www.linkedin.com/in/ACoAACBJyQMBG7vI0Z...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 802                                                NaN
# 803  https://www.linkedin.com/in/ACoAACtSD98BKfiq3v...
# 804  https://www.linkedin.com/in/ACoAABNrT7UB4evE1t...
# 805                                                NaN
# 806                                                NaN
#
#                      postedAt appliesClosed  \
# 0    2022-03-11T13:49:39.000Z         False
# 1    2022-02-23T11:38:28.000Z         False
# 2    2022-03-06T09:40:10.000Z         False
# 3    2022-03-07T01:49:27.000Z         False
# 4    2022-03-02T10:23:33.000Z         False
# ..                        ...           ...
# 802  2022-03-08T16:10:05.000Z         False
# 803  2022-02-09T07:14:42.000Z         False
# 804  2022-02-18T03:47:10.000Z         False
# 805  2022-03-10T11:29:42.000Z         False
# 806  2022-02-11T07:46:20.000Z         False
#
#                                               applyUrl  \
# 0    https://sggovterp.wd102.myworkdayjobs.com/en-U...
# 1    https://jobs.sea.deloitte.com/job/Singapore-Se...
# 2    https://careers.tiktok.com/position/7059246670...
# 3    https://sggovterp.wd102.myworkdayjobs.com/en-U...
# 4        https://www.linkedin.com/job-apply/2935644471
# ..                                                 ...
# 802  https://boards.greenhouse.io/acronis/jobs/5865...
# 803      https://www.linkedin.com/job-apply/2913886257
# 804      https://www.linkedin.com/job-apply/2926838444
# 805      https://www.linkedin.com/job-apply/2895248784
# 806      https://www.linkedin.com/job-apply/2917545050
#
#                                         jobDescription remoteAllowed  ...  \
# 0    The Government Technology Agency (GovTech) aim...         False  ...
# 1    At Deloitte, we offer a unique and exceptional...         False  ...
# 2    About TikTokTikTok is the leading destination ...         False  ...
# 3    The Government Technology Agency (GovTech) aim...         False  ...
# 4    This is a client facing / presales role, worki...          True  ...
# ..                                                 ...           ...  ...
# 802  Acronis is dedicated not just to cyber protect...         False  ...
# 803  Project Description\nWe are looking for a tale...         False  ...
# 804  Project DescriptionWe are looking for a talent...         False  ...
# 805  SALESFORCE MARKETING CLOUD (SFMC) TECHNICAL SP...         False  ...
# 806  Project DescriptionWe are looking for a talent...         False  ...
#
#     matchedSkills                                       jobFunctions  \
# 0             NaN                             Information Technology
# 1             NaN          Consulting, Information Technology, Sales
# 2             NaN                Engineering, Information Technology
# 3             NaN                             Information Technology
# 4             NaN  Information Technology, Consulting, Project Ma...
# ..            ...                                                ...
# 802           NaN                        Business Development, Sales
# 803           NaN                Engineering, Information Technology
# 804           NaN                             Information Technology
# 805           NaN                                   Marketing, Sales
# 806           NaN                Engineering, Information Technology
#
#                                          jobIndustries  \
# 0                    Information Technology & Services
# 1    Management Consulting, Information Technology ...
# 2                                             Internet
# 3                    Information Technology & Services
# 4                    Information Technology & Services
# ..                                                 ...
# 802                                  Computer Software
# 803  Information Technology & Services, Computer So...
# 804                  Information Technology & Services
# 805                  Information Technology & Services
# 806         Information Technology & Services, Banking
#
#               appliesClosedAt    jobType  \
# 0    2022-04-10T13:49:38.000Z  Full-time
# 1    2022-06-03T13:30:50.000Z  Full-time
# 2    2022-04-05T09:40:09.000Z  Full-time
# 3    2022-04-06T01:49:25.000Z  Full-time
# 4    2022-04-01T10:23:32.000Z  Full-time
# ..                        ...        ...
# 802  2022-04-07T16:10:04.000Z  Full-time
# 803  2022-03-11T07:14:41.000Z  Full-time
# 804  2022-03-20T03:47:10.000Z  Full-time
# 805  2022-04-26T19:39:02.000Z  Full-time
# 806  2022-03-13T07:46:19.000Z  Full-time
#
#                                              jobUrl  \
# 0    https://www.linkedin.com/jobs/view/2952531304/
# 1    https://www.linkedin.com/jobs/view/2705235394/
# 2    https://www.linkedin.com/jobs/view/2942975743/
# 3    https://www.linkedin.com/jobs/view/2944331585/
# 4    https://www.linkedin.com/jobs/view/2935644471/
# ..                                              ...
# 802  https://www.linkedin.com/jobs/view/2955575627/
# 803  https://www.linkedin.com/jobs/view/2913886257/
# 804  https://www.linkedin.com/jobs/view/2926838444/
# 805  https://www.linkedin.com/jobs/view/2895248784/
# 806  https://www.linkedin.com/jobs/view/2917545050/
#
#                                            jobImageUrl  \
# 0    https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# 1    https://media-exp1.licdn.com/dms/image/C4E0BAQ...
# 2    https://media-exp1.licdn.com/dms/image/C510BAQ...
# 3    https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# 4    https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# ..                                                 ...
# 802  https://media-exp1.licdn.com/dms/image/C510BAQ...
# 803  https://media-exp1.licdn.com/dms/image/C560BAQ...
# 804  https://media-exp1.licdn.com/dms/image/C560BAQ...
# 805  https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# 806  https://media-exp1.licdn.com/dms/image/C560BAQ...
#
#                     timestamp                                           query  \
# 0    2022-03-16T00:39:42.612Z  https://www.linkedin.com/jobs/view/2952531304/
# 1    2022-03-16T00:39:45.465Z  https://www.linkedin.com/jobs/view/2705235394/
# 2    2022-03-16T00:39:48.373Z  https://www.linkedin.com/jobs/view/2942975743/
# 3    2022-03-16T00:39:51.212Z  https://www.linkedin.com/jobs/view/2944331585/
# 4    2022-03-16T00:39:54.464Z  https://www.linkedin.com/jobs/view/2935644471/
# ..                        ...                                             ...
# 802  2022-03-15T04:33:58.399Z  https://www.linkedin.com/jobs/view/2955575627/
# 803  2022-03-15T04:34:01.335Z  https://www.linkedin.com/jobs/view/2913886257/
# 804  2022-03-15T04:34:04.603Z  https://www.linkedin.com/jobs/view/2926838444/
# 805  2022-03-15T04:34:07.586Z  https://www.linkedin.com/jobs/view/2895248784/
# 806  2022-03-15T04:34:10.644Z  https://www.linkedin.com/jobs/view/2917545050/
#
#     error
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 802   NaN
# 803   NaN
# 804   NaN
# 805   NaN
# 806   NaN
#
# [807 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   jobTitle             801 non-null    object
#  1   jobLocation          801 non-null    object
#  2   applicantsCount      773 non-null    float64
#  3   viewsCount           801 non-null    float64
#  4   jobPosterProfileUrl  164 non-null    object
#  5   postedAt             801 non-null    object
#  6   appliesClosed        801 non-null    object
#  7   applyUrl             768 non-null    object
#  8   jobDescription       801 non-null    object
#  9   remoteAllowed        801 non-null    object
#  10  companyName          801 non-null    object
#  11  companyUrl           765 non-null    object
#  12  matchedSkills        0 non-null      float64
#  13  jobFunctions         783 non-null    object
#  14  jobIndustries        740 non-null    object
#  15  appliesClosedAt      801 non-null    object
#  16  jobType              801 non-null    object
#  17  jobUrl               801 non-null    object
#  18  jobImageUrl          765 non-null    object
#  19  timestamp            807 non-null    object
#  20  query                807 non-null    object
#  21  error                6 non-null      object
# dtypes: float64(3), object(19)
# memory usage: 138.8+ KB

# %% [markdown]
# # Drop NA
# Happens when:
# 1. As Monster may direct users to the job posting in the company's website, the website format is different from Monster.
# Hence, data could not be scrapped for those job posting.
# 2. Usually if the salary is "Not specified" and years_experience is "undefined-undefined Years", the other fields will be NaN

# %%
# Drop job postings with errors (keep only postings with an empty error column)
df = df[df.error.isnull()]

# %% [markdown]
# # Date Posted

# %%
df['postedAt']
# Out:
# 0      2022-03-11T13:49:39.000Z
# 1      2022-02-23T11:38:28.000Z
# 2      2022-03-06T09:40:10.000Z
# 3      2022-03-07T01:49:27.000Z
# 4      2022-03-02T10:23:33.000Z
#                  ...
# 802    2022-03-08T16:10:05.000Z
# 803    2022-02-09T07:14:42.000Z
# 804    2022-02-18T03:47:10.000Z
# 805    2022-03-10T11:29:42.000Z
# 806    2022-02-11T07:46:20.000Z
# Name: postedAt, Length: 801, dtype: object

# %%
type(df['postedAt'][0])
# Out:
# str

# %%
# keep only the date
df['postedAt'] = [x[:10] for x in df['postedAt']]
df['postedAt']
# Out:
# 0      2022-03-11
# 1      2022-02-23
# 2      2022-03-06
# 3      2022-03-07
# 4      2022-03-02
#           ...
# 802    2022-03-08
# 803    2022-02-09
# 804    2022-02-18
# 805    2022-03-10
# 806    2022-02-11
# Name: postedAt, Length: 801, dtype: object

# %% [markdown]
# ## Remove duplicates
# Companies may post the same job a few times over a period of time. We will take the first post

# %%
# sort according to date
df.sort_values(by="postedAt", inplace=True)

# %%
# drop duplicates 
df.drop_duplicates(subset=['jobTitle', 'companyName', 'jobDescription'], keep='first', inplace=True)
df.reset_index(inplace=True, drop=True)
df
# Out:
#                                               jobTitle           jobLocation  \
# 0                            Cloud Consumption Analyst  Singapore, Singapore
# 1                       Senior Cloud Software Engineer  Singapore, Singapore
# 2    Pooling: Schneider Graduate Program Associate ...  Singapore, Singapore
# 3                               Infrastructure Analyst  Singapore, Singapore
# 4                   Junior Software Solutions Engineer  Singapore, Singapore
# ..                                                 ...                   ...
# 783              Inside Systems Engineer, Public Cloud  Singapore, Singapore
# 784            Cloud Business Development Leader, APAC  Singapore, Singapore
# 785                                Cloud Data Engineer  Singapore, Singapore
# 786        Cloud Software Engineer, Principal Engineer  Singapore, Singapore
# 787                 Cloud Security Operations Engineer  Singapore, Singapore
#
#      applicantsCount  viewsCount  \
# 0               19.0       368.0
# 1               45.0       580.0
# 2              135.0      1087.0
# 3                3.0        69.0
# 4               10.0       102.0
# ..               ...         ...
# 783             41.0       475.0
# 784             49.0       433.0
# 785             90.0       396.0
# 786              8.0       115.0
# 787             41.0       238.0
#
#                                    jobPosterProfileUrl    postedAt  \
# 0                                                  NaN  2021-10-07
# 1    https://www.linkedin.com/in/ACoAAADUtrsBMdWWpz...  2021-11-16
# 2                                                  NaN  2021-11-20
# 3                                                  NaN  2021-11-20
# 4                                                  NaN  2021-12-07
# ..                                                 ...         ...
# 783                                                NaN  2022-03-15
# 784                                                NaN  2022-03-15
# 785  https://www.linkedin.com/in/ACoAABVRW9oBB0fQxh...  2022-03-15
# 786                                                NaN  2022-03-15
# 787                                                NaN  2022-03-16
#
#     appliesClosed                                           applyUrl  \
# 0           False  https://www.applytracking.com/x.aspx?method=di...
# 1           False  https://boards.greenhouse.io/motional/jobs/464...
# 2           False  https://careers.se.com/jobs/0079VP?lang=en-us&...
# 3           False  https://www.capgemini.com/jobs/infrastructure-...
# 4           False  https://jobs.partnersgroup.com/job/Singapore-J...
# ..            ...                                                ...
# 783         False  https://veeam.wd3.myworkdayjobs.com/Veeam/job/...
# 784         False  https://boards.greenhouse.io/rubrik/jobs/37440...
# 785         False      https://www.linkedin.com/job-apply/2886038785
# 786         False  https://ars2.equest.com/?response_id=76dca38ed...
# 787         False  https://jobs.sap.com/job/Singapore-DevOps-Engi...
#
#                                         jobDescription remoteAllowed  ...  \
# 0    Job Description\n\nThe Cloud Consumption Analy...         False  ...
# 1    We are seeking talented Senior Cloud Software ...         False  ...
# 2    Great People make Schneider Electric a great c...         False  ...
# 3    Who are we?\n\nCloud and Edge is a projects an...         False  ...
# 4    What It's About\n\nT he Business Applications ...         False  ...
# ..                                                 ...           ...  ...
# 783  The Inside Systems Engineer is responsible for...         False  ...
# 784  Overview\n\nRubrik, the Zero Trust Data Securi...         False  ...
# 785  NCS is a leading technology services firm with...         False  ...
# 786  As an experienced member of our Software Engin...         False  ...
# 787  What We Offer\n\nOur company culture is focuse...         False  ...
#
#     matchedSkills                                       jobFunctions  \
# 0             NaN                             Information Technology
# 1             NaN                                        Engineering
# 2             NaN                                     Administrative
# 3             NaN                             Information Technology
# 4             NaN                Engineering, Information Technology
# ..            ...                                                ...
# 783           NaN                                              Sales
# 784           NaN                        Business Development, Sales
# 785           NaN  Sales, Business Development, Information Techn...
# 786           NaN                Engineering, Information Technology
# 787           NaN                         Design, Product Management
#
#                                          jobIndustries  \
# 0                                       Semiconductors
# 1                                           Automotive
# 2                                                  NaN
# 3                          Computer & Network Security
# 4            Investment Management, Financial Services
# ..                                                 ...
# 783                  Information Technology & Services
# 784                                  Computer Software
# 785                  Information Technology & Services
# 786                                    Capital Markets
# 787  Computer Software, Information Technology & Se...
#
#               appliesClosedAt    jobType  \
# 0    2022-03-20T04:06:49.000Z  Full-time
# 1    2022-07-30T07:51:08.000Z  Full-time
# 2    2022-04-06T05:41:12.000Z  Full-time
# 3    2022-04-06T03:54:32.000Z  Full-time
# 4    2022-03-28T16:12:33.000Z  Full-time
# ..                        ...        ...
# 783  2022-06-12T03:27:09.000Z  Full-time
# 784  2022-05-09T16:59:42.000Z  Full-time
# 785  2022-04-21T03:11:17.000Z  Full-time
# 786  2022-04-22T11:53:50.000Z  Full-time
# 787  2022-05-02T09:17:53.000Z  Full-time
#
#                                              jobUrl  \
# 0    https://www.linkedin.com/jobs/view/2773797384/
# 1    https://www.linkedin.com/jobs/view/2707798083/
# 2    https://www.linkedin.com/jobs/view/2837955500/
# 3    https://www.linkedin.com/jobs/view/2841040035/
# 4    https://www.linkedin.com/jobs/view/2821971962/
# ..                                              ...
# 783  https://www.linkedin.com/jobs/view/2753103764/
# 784  https://www.linkedin.com/jobs/view/2869881810/
# 785  https://www.linkedin.com/jobs/view/2886038785/
# 786  https://www.linkedin.com/jobs/view/2923852700/
# 787  https://www.linkedin.com/jobs/view/2900380137/
#
#                                            jobImageUrl  \
# 0    https://media-exp1.licdn.com/dms/image/C560BAQ...
# 1    https://media-exp1.licdn.com/dms/image/C560BAQ...
# 2    https://media-exp1.licdn.com/dms/image/C4E0BAQ...
# 3    https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# 4    https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# ..                                                 ...
# 783  https://media-exp1.licdn.com/dms/image/C560BAQ...
# 784  https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# 785  https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# 786  https://media-exp1.licdn.com/dms/image/C510BAQ...
# 787  https://media-exp1.licdn.com/dms/image/C4D0BAQ...
#
#                     timestamp                                           query  \
# 0    2022-03-14T04:07:59.226Z  https://www.linkedin.com/jobs/view/2773797384/
# 1    2022-03-14T11:19:42.877Z  https://www.linkedin.com/jobs/view/2707798083/
# 2    2022-03-14T04:07:32.792Z  https://www.linkedin.com/jobs/view/2837955500/
# 3    2022-03-15T20:06:55.957Z  https://www.linkedin.com/jobs/view/2841040035/
# 4    2022-03-15T20:09:02.310Z  https://www.linkedin.com/jobs/view/2821971962/
# ..                        ...                                             ...
# 783  2022-03-16T00:44:49.434Z  https://www.linkedin.com/jobs/view/2753103764/
# 784  2022-03-17T02:35:34.505Z  https://www.linkedin.com/jobs/view/2869881810/
# 785  2022-03-16T00:41:17.801Z  https://www.linkedin.com/jobs/view/2886038785/
# 786  2022-03-17T02:34:25.135Z  https://www.linkedin.com/jobs/view/2923852700/
# 787  2022-03-17T02:34:45.195Z  https://www.linkedin.com/jobs/view/2900380137/
#
#     error
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 783   NaN
# 784   NaN
# 785   NaN
# 786   NaN
# 787   NaN
#
# [788 rows x 22 columns]

# %% [markdown]
# # Job Type

# %%
df['jobType'].unique()
# Out:
# array(['Full-time', 'Internship', 'Part-time', 'Contract', 'Temporary'],
#       dtype=object)

# %%
# may need to change depending on the job types available in the platform
def clean_job_type(text):
    if 'full-time' in text.lower():
        return 'permanent'
    # take temporary and part-time as contract work
    elif ('contract' in text.lower()) or ('temporary' in text.lower()) or ('part-time' in text.lower()):
        return 'contract'
    elif 'internship' in text.lower():
        return 'intern'
    else: 
        return np.nan

# %%
df['jobType'] = df['jobType'].apply(lambda x: clean_job_type(str(x)))
df
# Out:
#                                               jobTitle           jobLocation  \
# 0                            Cloud Consumption Analyst  Singapore, Singapore
# 1                       Senior Cloud Software Engineer  Singapore, Singapore
# 2    Pooling: Schneider Graduate Program Associate ...  Singapore, Singapore
# 3                               Infrastructure Analyst  Singapore, Singapore
# 4                   Junior Software Solutions Engineer  Singapore, Singapore
# ..                                                 ...                   ...
# 783              Inside Systems Engineer, Public Cloud  Singapore, Singapore
# 784            Cloud Business Development Leader, APAC  Singapore, Singapore
# 785                                Cloud Data Engineer  Singapore, Singapore
# 786        Cloud Software Engineer, Principal Engineer  Singapore, Singapore
# 787                 Cloud Security Operations Engineer  Singapore, Singapore
#
#      applicantsCount  viewsCount  \
# 0               19.0       368.0
# 1               45.0       580.0
# 2              135.0      1087.0
# 3                3.0        69.0
# 4               10.0       102.0
# ..               ...         ...
# 783             41.0       475.0
# 784             49.0       433.0
# 785             90.0       396.0
# 786              8.0       115.0
# 787             41.0       238.0
#
#                                    jobPosterProfileUrl    postedAt  \
# 0                                                  NaN  2021-10-07
# 1    https://www.linkedin.com/in/ACoAAADUtrsBMdWWpz...  2021-11-16
# 2                                                  NaN  2021-11-20
# 3                                                  NaN  2021-11-20
# 4                                                  NaN  2021-12-07
# ..                                                 ...         ...
# 783                                                NaN  2022-03-15
# 784                                                NaN  2022-03-15
# 785  https://www.linkedin.com/in/ACoAABVRW9oBB0fQxh...  2022-03-15
# 786                                                NaN  2022-03-15
# 787                                                NaN  2022-03-16
#
#     appliesClosed                                           applyUrl  \
# 0           False  https://www.applytracking.com/x.aspx?method=di...
# 1           False  https://boards.greenhouse.io/motional/jobs/464...
# 2           False  https://careers.se.com/jobs/0079VP?lang=en-us&...
# 3           False  https://www.capgemini.com/jobs/infrastructure-...
# 4           False  https://jobs.partnersgroup.com/job/Singapore-J...
# ..            ...                                                ...
# 783         False  https://veeam.wd3.myworkdayjobs.com/Veeam/job/...
# 784         False  https://boards.greenhouse.io/rubrik/jobs/37440...
# 785         False      https://www.linkedin.com/job-apply/2886038785
# 786         False  https://ars2.equest.com/?response_id=76dca38ed...
# 787         False  https://jobs.sap.com/job/Singapore-DevOps-Engi...
#
#                                         jobDescription remoteAllowed  ...  \
# 0    Job Description\n\nThe Cloud Consumption Analy...         False  ...
# 1    We are seeking talented Senior Cloud Software ...         False  ...
# 2    Great People make Schneider Electric a great c...         False  ...
# 3    Who are we?\n\nCloud and Edge is a projects an...         False  ...
# 4    What It's About\n\nT he Business Applications ...         False  ...
# ..                                                 ...           ...  ...
# 783  The Inside Systems Engineer is responsible for...         False  ...
# 784  Overview\n\nRubrik, the Zero Trust Data Securi...         False  ...
# 785  NCS is a leading technology services firm with...         False  ...
# 786  As an experienced member of our Software Engin...         False  ...
# 787  What We Offer\n\nOur company culture is focuse...         False  ...
#
#     matchedSkills                                       jobFunctions  \
# 0             NaN                             Information Technology
# 1             NaN                                        Engineering
# 2             NaN                                     Administrative
# 3             NaN                             Information Technology
# 4             NaN                Engineering, Information Technology
# ..            ...                                                ...
# 783           NaN                                              Sales
# 784           NaN                        Business Development, Sales
# 785           NaN  Sales, Business Development, Information Techn...
# 786           NaN                Engineering, Information Technology
# 787           NaN                         Design, Product Management
#
#                                          jobIndustries  \
# 0                                       Semiconductors
# 1                                           Automotive
# 2                                                  NaN
# 3                          Computer & Network Security
# 4            Investment Management, Financial Services
# ..                                                 ...
# 783                  Information Technology & Services
# 784                                  Computer Software
# 785                  Information Technology & Services
# 786                                    Capital Markets
# 787  Computer Software, Information Technology & Se...
#
#               appliesClosedAt    jobType  \
# 0    2022-03-20T04:06:49.000Z  permanent
# 1    2022-07-30T07:51:08.000Z  permanent
# 2    2022-04-06T05:41:12.000Z  permanent
# 3    2022-04-06T03:54:32.000Z  permanent
# 4    2022-03-28T16:12:33.000Z  permanent
# ..                        ...        ...
# 783  2022-06-12T03:27:09.000Z  permanent
# 784  2022-05-09T16:59:42.000Z  permanent
# 785  2022-04-21T03:11:17.000Z  permanent
# 786  2022-04-22T11:53:50.000Z  permanent
# 787  2022-05-02T09:17:53.000Z  permanent
#
#                                              jobUrl  \
# 0    https://www.linkedin.com/jobs/view/2773797384/
# 1    https://www.linkedin.com/jobs/view/2707798083/
# 2    https://www.linkedin.com/jobs/view/2837955500/
# 3    https://www.linkedin.com/jobs/view/2841040035/
# 4    https://www.linkedin.com/jobs/view/2821971962/
# ..                                              ...
# 783  https://www.linkedin.com/jobs/view/2753103764/
# 784  https://www.linkedin.com/jobs/view/2869881810/
# 785  https://www.linkedin.com/jobs/view/2886038785/
# 786  https://www.linkedin.com/jobs/view/2923852700/
# 787  https://www.linkedin.com/jobs/view/2900380137/
#
#                                            jobImageUrl  \
# 0    https://media-exp1.licdn.com/dms/image/C560BAQ...
# 1    https://media-exp1.licdn.com/dms/image/C560BAQ...
# 2    https://media-exp1.licdn.com/dms/image/C4E0BAQ...
# 3    https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# 4    https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# ..                                                 ...
# 783  https://media-exp1.licdn.com/dms/image/C560BAQ...
# 784  https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# 785  https://media-exp1.licdn.com/dms/image/C4D0BAQ...
# 786  https://media-exp1.licdn.com/dms/image/C510BAQ...
# 787  https://media-exp1.licdn.com/dms/image/C4D0BAQ...
#
#                     timestamp                                           query  \
# 0    2022-03-14T04:07:59.226Z  https://www.linkedin.com/jobs/view/2773797384/
# 1    2022-03-14T11:19:42.877Z  https://www.linkedin.com/jobs/view/2707798083/
# 2    2022-03-14T04:07:32.792Z  https://www.linkedin.com/jobs/view/2837955500/
# 3    2022-03-15T20:06:55.957Z  https://www.linkedin.com/jobs/view/2841040035/
# 4    2022-03-15T20:09:02.310Z  https://www.linkedin.com/jobs/view/2821971962/
# ..                        ...                                             ...
# 783  2022-03-16T00:44:49.434Z  https://www.linkedin.com/jobs/view/2753103764/
# 784  2022-03-17T02:35:34.505Z  https://www.linkedin.com/jobs/view/2869881810/
# 785  2022-03-16T00:41:17.801Z  https://www.linkedin.com/jobs/view/2886038785/
# 786  2022-03-17T02:34:25.135Z  https://www.linkedin.com/jobs/view/2923852700/
# 787  2022-03-17T02:34:45.195Z  https://www.linkedin.com/jobs/view/2900380137/
#
#     error
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 783   NaN
# 784   NaN
# 785   NaN
# 786   NaN
# 787   NaN
#
# [788 rows x 22 columns]

# %% [markdown]
# # Remove unnecessary columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788 entries, 0 to 787
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   jobTitle             788 non-null    object
#  1   jobLocation          788 non-null    object
#  2   applicantsCount      760 non-null    float64
#  3   viewsCount           788 non-null    float64
#  4   jobPosterProfileUrl  161 non-null    object
#  5   postedAt             788 non-null    object
#  6   appliesClosed        788 non-null    object
#  7   applyUrl             755 non-null    object
#  8   jobDescription       788 non-null    object
#  9   remoteAllowed        788 non-null    object
#  10  companyName          788 non-null    object
#  11  companyUrl           753 non-null    object
#  12  matchedSkills        0 non-null      float64
#  13  jobFunctions         770 non-null    object
#  14  jobIndustries        728 non-null    object
#  15  appliesClosedAt      788 non-null    object
#  16  jobType              788 non-null    object
#  17  jobUrl               788 non-null    object
#  18  jobImageUrl          753 non-null    object
#  19  timestamp            788 non-null    object
#  20  query                788 non-null    object
#  21  error                0 non-null      object
# dtypes: float64(3), object(19)
# memory usage: 135.6+ KB

# %%
# all these columns are irrelevant, location is all singapore
df.drop(columns = ['error', 'matchedSkills', 'appliesClosedAt', 'viewsCount', 'jobLocation', 'jobPosterProfileUrl', 'appliesClosed', 'applyUrl', 'appliesClosedAt', 'jobImageUrl', 'query', 'error', 'timestamp'], inplace=True)

# %% [markdown]
# # Rename columns

# %%
df.columns
# Out:
# Index(['jobTitle', 'applicantsCount', 'postedAt', 'jobDescription',
#        'remoteAllowed', 'companyName', 'companyUrl', 'jobFunctions',
#        'jobIndustries', 'jobType', 'jobUrl'],
#       dtype='object')

# %%
rename = {
    'jobTitle': 'job_title',
    'jobUrl': 'url',
    'postedAt': 'date_posted',
    'companyName': 'company_name',
    'jobIndustries': 'industry',
    'jobFunctions': 'job_functions',
    'jobDescription': 'job_desc',
    'jobType': 'job_type'
}

df.rename(columns=rename, inplace=True)

# %%
# Change directory and filename
save_dir = "/Users/joshuawong/Documents/GitHub/job-posting-analysis/data/cleaned"
df.to_csv(f'{save_dir}/LinkedIn.csv', index=False)

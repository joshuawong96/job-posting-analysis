# %%
import pandas as pd

# %% [markdown]
# ### Reading Raw Data

# %%
nodeflair_data = pd.read_csv("../data/raw/nodeflair/nodeflair_jobpostings.csv", index_col=0)

nodeflair_data.head(1)
# Out:
#            URL         Date posted  \
# 0  /jobs/53907  about 11 hours ago
#
#                                                 data  \
# 0  ['ReactJS Developer (Full Stack)', 'Apar Techn...
#
#                         Job Title       Company Name          Seniority  \
# 0  ReactJS Developer (Full Stack)  Apar Technologies  ['Mid', 'Junior']
#
#                           Salary   Job Type Years of Experience  \
# 0  $6,419 - $8,819 SGD / Monthly  Permanent           2-3 years
#
#                                           Tech Stack  \
# 0  ['Docker', 'CloudFoundry', 'Spring', 'SonarQub...
#
#                                             Job Desc cleaned_date
# 0  We are looking for a candidate to fill in the ...   2022-03-10

# %% [markdown]
# ### Functions to clean Years of Experience and Salary to a standardised format

# %%
def clean_years_of_experience(text):
    if text == "Information not provided":
        return "NaN"
    elif "At least" in text:
        text = text.replace("At least","")
        return [int(text.split()[0])]
    else:
        years = text.split()[0]
        range = years.split("-")
        lower_limit = int(range[0])
        upper_limit = int(range[1])
        return [lower_limit, upper_limit]

# %%
def clean_salary(text):
    if text != "-":
        salary = text.split('SGD')[0]
        range = salary.split("-")
        lower_limit = range[0][1:-1]
        upper_limit = range[1][2:-1]
        return [lower_limit, upper_limit]
    else:
        return "NaN"

# %%
def clean_url(text):
    text = 'https://www.nodeflair.com/' + text

    return text

# %%
nodeflair_data["URL"] = nodeflair_data["URL"].apply(clean_url)
nodeflair_data["Salary"] = nodeflair_data["Salary"].apply(clean_salary)
nodeflair_data["Years of Experience"] = nodeflair_data["Years of Experience"].apply(clean_years_of_experience)

nodeflair_data.head(1)
# Out:
#                                      URL         Date posted  \
# 0  https://www.nodeflair.com//jobs/53907  about 11 hours ago
#
#                                                 data  \
# 0  ['ReactJS Developer (Full Stack)', 'Apar Techn...
#
#                         Job Title       Company Name          Seniority  \
# 0  ReactJS Developer (Full Stack)  Apar Technologies  ['Mid', 'Junior']
#
#            Salary   Job Type Years of Experience  \
# 0  [6,419, 8,819]  Permanent              [2, 3]
#
#                                           Tech Stack  \
# 0  ['Docker', 'CloudFoundry', 'Spring', 'SonarQub...
#
#                                             Job Desc cleaned_date
# 0  We are looking for a candidate to fill in the ...   2022-03-10

# %% [markdown]
# ### Rename Columns and drop irrelevant ones

# %%
nodeflair_data.rename(columns={'URL':'url', 
                        'cleaned_date':'date_posted',
                        'Job Title':'job_title',
                        'Company Name':'company_name',
                        'Salary':'salary',
                        'Job Type':'job_type',
                        'Years of Experience': 'years_of_experience',
                        'Tech Stack':'tech_stack',
                        'Job Desc':'job_desc'}, inplace=True)

nodeflair_data.head(1)
# Out:
#                                      url         Date posted  \
# 0  https://www.nodeflair.com//jobs/53907  about 11 hours ago
#
#                                                 data  \
# 0  ['ReactJS Developer (Full Stack)', 'Apar Techn...
#
#                         job_title       company_name          Seniority  \
# 0  ReactJS Developer (Full Stack)  Apar Technologies  ['Mid', 'Junior']
#
#            salary   job_type years_of_experience  \
# 0  [6,419, 8,819]  Permanent              [2, 3]
#
#                                           tech_stack  \
# 0  ['Docker', 'CloudFoundry', 'Spring', 'SonarQub...
#
#                                             job_desc date_posted
# 0  We are looking for a candidate to fill in the ...  2022-03-10

# %%
nodeflair_data.drop(["Date posted", "data", "Seniority"], axis=1, inplace=True)

# %% [markdown]
# ### Check for duplicates

# %%
nodeflair_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2901 entries, 0 to 2900
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   url                  2901 non-null   object
#  1   job_title            2901 non-null   object
#  2   company_name         2901 non-null   object
#  3   salary               2901 non-null   object
#  4   job_type             2901 non-null   object
#  5   years_of_experience  2901 non-null   object
#  6   tech_stack           2901 non-null   object
#  7   job_desc             2901 non-null   object
#  8   date_posted          2143 non-null   object
# dtypes: object(9)
# memory usage: 226.6+ KB

# %%
nodeflair_data.drop_duplicates(subset=['company_name', 'job_title','job_desc'], inplace=True)
nodeflair_data
# Out:
#                                         url  \
# 0     https://www.nodeflair.com//jobs/53907
# 1     https://www.nodeflair.com//jobs/53898
# 2     https://www.nodeflair.com//jobs/53894
# 3     https://www.nodeflair.com//jobs/53893
# 4     https://www.nodeflair.com//jobs/53891
# ...                                     ...
# 2896  https://www.nodeflair.com//jobs/46156
# 2897  https://www.nodeflair.com//jobs/46153
# 2898  https://www.nodeflair.com//jobs/46151
# 2899  https://www.nodeflair.com//jobs/46149
# 2900  https://www.nodeflair.com//jobs/46147
#
#                                    job_title  \
# 0             ReactJS Developer (Full Stack)
# 1                               Manager, SRE
# 2                            DevOps Engineer
# 3                         VP, System Analyst
# 4           DevOps & Lab Manager (SG - Edge)
# ...                                      ...
# 2896                         DevOps Engineer
# 2897                         DevOps Engineer
# 2898                         DevOps Engineer
# 2899                       Software Engineer
# 2900  Sr. Site Reliability Engineer - Hadoop
#
#                             company_name            salary   job_type  \
# 0                      Apar Technologies    [6,419, 8,819]  Permanent
# 1                           Rakuten Viki               NaN  Permanent
# 2                                GovTech    [5,800, 9,600]  Permanent
# 3     United Overseas Bank Limited (UOB)               NaN  Permanent
# 4                      Dell Technologies  [11,000, 22,000]  Permanent
# ...                                  ...               ...        ...
# 2896                                2C2P   [7,000, 10,000]  Permanent
# 2897                             FINXFLO               NaN  Permanent
# 2898                            Quilt.AI               NaN  Permanent
# 2899            Zoku Integrated Commerce               NaN  Permanent
# 2900                   Xiaomi Technology               NaN  Permanent
#
#      years_of_experience                                         tech_stack  \
# 0                 [2, 3]  ['Docker', 'CloudFoundry', 'Spring', 'SonarQub...
# 1                    NaN  ['Docker', 'API', 'PagerDuty', 'GKE', 'ELK', '...
# 2                    [2]  ['Docker', 'DockerCompose', 'Fluentd', 'Clair'...
# 3               [10, 15]  ['ETL', 'Oracle', 'Experian', 'Strategy', 'Ter...
# 4                   [12]  ['Docker', 'Strategy', 'Container', 'Microsoft...
# ...                  ...                                                ...
# 2896                 [3]  ['GitLab', 'HTTP', 'UDP', 'TCP', 'ShellScript'...
# 2897                 NaN  ['Strategy', 'ShellScript', 'CI', 'Shell', 'UN...
# 2898                 [3]  ['Next.js', 'Docker', 'Cloudflare', 'DockerSwa...
# 2899                 [3]  ['API', 'Magento', 'CI', 'DOM', 'Node.js', 'No...
# 2900                 NaN  ['MapReduce', 'API', 'Container', 'JMX', 'Anal...
#
#                                                job_desc date_posted
# 0     We are looking for a candidate to fill in the ...  2022-03-10
# 1     The SRE team at Viki is responsible for buildi...  2022-03-10
# 2     Our team in GovTech works on highly impactful ...  2022-03-10
# 3     The Technology and Operations function is comp...  2022-03-10
# 4     Dell Technologies is seeking an entrepreneuria...  2022-03-10
# ...                                                 ...         ...
# 2896  2C2P is looking for a .NET DevOps Engineer to ...  2022-01-11
# 2897  Alpha Stone Capital is looking for an amazing ...  2022-01-11
# 2898  As part of a growing team consisting of ML exp...  2022-01-11
# 2899  We are hiring software engineers with expertis...  2022-01-11
# 2900  Job Requirement： Deploy, operate, maintain, se...  2022-01-11
#
# [2245 rows x 9 columns]

# %%
nodeflair_data.to_csv("../data/cleaned/cleaned_nodeflair_jobpostings.csv")
